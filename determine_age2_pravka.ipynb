# %% [markdown]
# Привет, меня зовут Люман Аблаев. Сегодня я проверю твой проект.
# <br> Дальнейшее общение будет происходить на "ты" если это не вызывает никаких проблем.
# <br> Желательно реагировать на красные комментарии ('исправил', 'не понятно как исправить ошибку', ...)
# <br> Пожалуйста, не удаляй комментарии ревьюера, так как они повышают качество повторного ревью.
#
# Комментарии будут в <font color='green'>зеленой</font>, <font color='blue'>синей</font> или <font color='red'>красной</font> рамках:
#
#
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Если все сделано отлично
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Совет: </b> Если можно немного улучшить
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Ошибка:</b> Если требуются исправления. Работа не может быть принята с красными комментариями.
# </div>
#
# -------------------
#
# Будет очень хорошо, если ты будешь помечать свои действия следующим образом:
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b> ...
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Изменения:</b> Были внесены следующие изменения ...
# </div>
#
#
#
#
# <font color='orange' style='font-size:24px; font-weight:bold'>Общее впечатление</font>
# * Спасибо за очень качественную работу - видно, что вложено много труда.
# - Я оставил некоторые советы, надеюсь они будут полезными и интересными
# - Есть некоторые недочеты, которые нужно поправить, но у тебя это не должно занять много времени)
# - Жду обновленную работу

# %% [markdown]
# Ссылка на Githab:
# https://github.com/Konopatskaya/Yeti
# _______________
# # Классификация пользователей на группы по возрастным интервалам
# _______________
#
# **Описание исследования**. IT-компания «Йети», управляет группой популярных интернет-сервисов. Каждый день через них проходят миллионы пользователей. Значительную часть дохода компания получает от контекстной рекламы. В связи с этим, важно показывать рекламу (таргетировать рекламу) своей группе пользователей, в зависимости от возраста. Чем больше рекламу посмотрит целевая аудитория, тем больше коэффициент кликабельности CTR и, следовательно, прибыли получит компания. Таргетированная реклама  - это привлечение прибыли, повышение качества услуг и имиджа компании.
#
# 1. Тип: Задача обучения с учителем
# 2. Целевая перерменная (Target): `age_category` — возрастная категория пользователя, этот показатель модель должна научиться предсказывать. Признак многоклассовой классфикации, где:
#   -  0: младше 18;
#   -  1: 18-25 лет;
#   -  2: 26-40 лет;
#   -  3: 41-55 лет;
#   -  4: 56+ лет.
# _______________
#
# **Цель исследования** - построить предсказательную модель многоклассовой классификации, которая разделяет пользователей на несколько групп по возрастным интервалам.
#
# Бизнес-контекст и цель:
# - Проблема: отсутствует таргетированная по возрастым группам реклама. Маркетологи тратят много сил и средств, чтобы узнать, какой возрастной категории будет интересен продвигаемый товар. Для них выяснить возраст целевой аудитории — это не просто хорошая практика, а залог эффективности рекламы. Одна из задач отделов маркетинга — научиться показывать рекламу нужным пользователям
# - Цель бизнеса: увеличить прибыли и качество сервисов за счёт таргетированной по возрасту рекламы.
# - Цель ML: построить модель многоклассовой классификации, которая делит пользователей на 4 возрастных группы. Это позволит повысить качество маркетинговых мероприятий и эффективность рекламных кампаний для своего пользователя.
# _________________________
#
# **Задачи исследования**
# 1.	Подготовка среды и библиотек.
# 2.	Исследовательский анализ данных.
# 3.	Предобработка данных.
# 4.	Обучение и оценка базовой модели.
# 5.	Создание и отбор признаков.
# 6.	Подбор гиперпараметров моделей.
# 7.	Подготовка артефактов модели для внедрения.
# 8.	Выводы о результатах работы.
#
# __________________________
#
# **Технические требования к модели и её обучению**
#
# -	Данные представлены в нескольких CSV-файлах (6 файлов). Они получены из разных источников.
# -	Все виды предобработки должны производиться так, чтобы избежать утечки данных из тестовой выборки в обучающую. Это особенно важно учесть при заполнении пропусков, кодировании категориальных признаков и масштабировании числовых.
# -	Тип модели. Некоторые входные признаки могут быть связаны с целевой переменной **нелинейно**. Поэтому помимо **LogisticRegression** буде использзовать модели **опорных векторов с разными ядрами**. В качестве базовой модели будем использовать DummyClassifier. Требуется подберать оптимальные гиперпараметры для каждой архитектуры.
# - Валидация. Для оценки качества модели при обучении планируем применяйть кросс-валидацию. При разделении данных на выборки и фолды использовать стратификацию по целевой переменной, чтобы сохранить пропорции классов.
# - Метрики качества. В качестве основной метрики будем использовать F1-меру. Вспомогательные метрики качества: precision и recall. Модель нужно оценить одинаково по всем классам, даже если один из них встречается редко, поэтому используйте макро-усреднение.
# - Значение F1-меры лучшей модели должно быть не меньше **0.75** и на кросс-валидации по обучающей выборке, и на тестовой выборке. В этом случае модель можно рекомендовать к внедрению.
# - Подготовка к внедрению. Необходимо сохранить не только итоговую модель, но и весь пайплайн предобработки данных.
# _______________________________
#
# **Исходные данные**
#
# 1.  Таблица `users`
# Таблица ds_s13_users.csv содержит информацию о возрастной категории пользователя:
# -	user_id — уникальный идентификатор пользователя.
# -	age_category — возрастная категория пользователя, этот показатель модель должна научиться предсказывать. Содержит следующие категории:
# -	0: младше 18;
# -	1: 18-25 лет;
# -	2: 26-40 лет;
# -	3: 41-55 лет;
# -	4: 56+ лет.
# 2. Таблица `visits`
#
# Лог посещений сайтов ds_s13_visits.csv похож на данные сервиса веб-аналитики «Яндекс Метрика». Он предназначен для сбора и анализа информации об активности пользователей разных сайтов. Заказчик попросил в целях защиты персональных данных заменить в логах все URL на анонимизированную категорию сайта, а вместо точного времени использовать время суток.
#
# Признаки в датасете:
# -	date — дата посещения сайта.
# -	daytime — анонимизированное время посещения сайта. Категории: утро, день, вечер, ночь.
# -	session_id — уникальный идентификатор сессии. Сессия — это последовательность действий пользователя на сайте, которая начинается при первом взаимодействии с ресурсом и завершается по правилам тайм-аута или смены условий.
# -	user_id — уникальный идентификатор пользователя.
# -	website_category — анонимизированная категория сайта. В лог включены несколько десятков категорий, которые позволяют эффективно сегментировать аудиторию. Это позволяет сократить пространство признаков модели без потери её качества.
# Таблица ads_activity
# Активность взаимодействия пользователя с рекламными объявлениями — важный показатель, связанный с возрастом. Информация об этом признаке представлена в таблице ads_activity.csv:
# -	user_id — уникальный идентификатор пользователя.
# -	ads_activity — характеристика CTR, выраженная одним из значений: очень редко, редко, умеренно, часто, очень часто.
#
# 3. Таблица `surf_depth`
#
# В таблице surf_depth.csv содержится два признака:
# -	user_id — уникальный идентификатор пользователя.
# -	surf_depth — категориальная переменная, характеризующая глубину перехода пользователя по сайтам во время одной сессии. Содержит категории поверхностно, средне, глубоко.
# Таблица primary_device
#
# 4. Таблица `primary_device.csv` содержит два признака:
# -	user_id — уникальный идентификатор пользователя.
# -	primary_device — информация о типе основного устройства пользователя для выхода в Интернет.
# Такие данные о пользователях можно взять на сервисах типа Крипты. Каждое устройство и браузер, которым человек пользуется для выхода в интернет, имеет свой уникальный идентификатор. Крипта умеет определять, что все эти идентификаторы принадлежат одному пользователю, по схожести его поведения на разных устройствах или по более точным факторам: например, по использованию одного и того же логина. Также учитывается, что одним устройством могут пользоваться сразу несколько человек: члены семьи или коллеги. Так Крипта составляет более полный портрет пользователя.
#
# 5. Таблица `cloud_usage`
#
# Использование облачных технологий описано в файле cloud_usage.csv:
# -	user_id — уникальный идентификатор пользователя;
# -	cloud_usage — True означает, что пользователь обращается к облачным ресурсам типа Яндекс 360 прямо или через посещаемые сайты.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Заголовок, бизнес-контекст, цель ML, целевая переменная, основная и вспомогательные метрики, пороговое значение F1 — всё указано корректно и подробно.
# </div>

# %% [markdown]
# ## Подготовка среды и библиотек

# %%
# !pip install -r requirements.txt

# %%
# Библиотеки для работы с данными и визуализации
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from phik import phik_matrix
import joblib
# Основная библиотека машинного обучения
import sklearn
import json
import uuid
import datetime


from datetime import datetime
# Классы из sklearn для разбиения данных и кросс-валидации
from sklearn.model_selection import train_test_split, KFold, cross_validate, StratifiedKFold
from sklearn.model_selection import StratifiedShuffleSplit#, GroupShuffleSplit

# Классы для построения пайплайнов
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
#  для надежности установить опцию в sklearn, чтобы он всегда в пандас выводил
# Шаг 1: Импортируем функцию
from sklearn import set_config
# Шаг 2: Вызываем функцию для изменения глобальной настройки
set_config(transform_output="pandas")

# Трансформеры для предобработки данных
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import VarianceThreshold
from sklearn.compose import make_column_transformer

# Модель для классификации
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, accuracy_score, recall_score, precision_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.dummy import DummyClassifier
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
#from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.feature_selection import RFE
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.inspection import permutation_importance

# %%
print("Scikit-learn version:", sklearn.__version__)
# Out:
# Scikit-learn version: 1.7.2

# %% [markdown]
# Настраиваем единообразное отображение графиков

# %%
plt.rcParams.update({
    "figure.figsize": (12, 8),   # Размер графика
    "font.size": 14,             # Размер шрифта по умолчанию
    "lines.linewidth": 2          # Толщина линий на графике
})

# %% [markdown]
# **Котстанты**

# %%
RANDOM_SEED=42

# %% [markdown]
# Зафиксирую cv для моделей кросс-валидации

# %%
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_SEED)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Совет:</b> Импортируются, но не используются: <code>GroupShuffleSplit</code>, <code>SequentialFeatureSelector</code> (mlxtend), <code>average_precision_score</code>, <code>CountEncoder</code>/<code>category_encoders</code> (в итоге применяется sklearn <code>OneHotEncoder</code>). Оставляйте в импортах только то, что реально используется ниже.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b> Спасибо, убрала лишнее.
# </div>

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# **Опишем базовую информацию о каждом  датасете.**
#
# - изменим названия и метки полей
# - оптимизируем типы полей
# - проверим пропуски
# - удалим явные и неявные дубликаты

# %% [markdown]
# Загрузим информацию из csv файлов

# %%
df_ads_activity=pd.read_csv('ads_activity.csv', decimal='.')

# %%
df_cloud_usage=pd.read_csv('cloud_usage.csv', decimal='.')

# %%
df_ds_s13_users=pd.read_csv('ds_s13_users.csv', decimal='.')

# %%
df_ds_s13_visits=pd.read_csv('ds_s13_visits.csv', decimal='.')

# %%
df_primary_device=pd.read_csv('primary_device.csv', decimal='.')

# %%
df_surf_depth=pd.read_csv('surf_depth.csv', decimal='.')

# %% [markdown]
# ### `df_ads_activity` Базовая информация о файле **ads_activity.csv**

# %%
df_ads_activity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5826 entries, 0 to 5825
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_id       5826 non-null   object
#  1   ads_activity  5826 non-null   object
# dtypes: object(2)
# memory usage: 91.2+ KB

# %%
df_ads_activity.head()
# Out:
#                               user_id ads_activity
# 0  e318-d8e69c86b543a5fb927c-c36fb6e6  очень часто
# 1  35cd-a972339dec534f49332c-a8b6d383        редко
# 2  f7e6-3b29cf9cb7ed4bb00d8f-81534360  очень редко
# 3  5186-e25a37549e50f45b2b43-178eaabe     умеренно
# 4  febd-077f277466253ee04ef6-42656680     умеренно

# %%
BOLD = '\033[1m'
RESET = '\033[0m'
def show_df(tmp0):
    # Приводим наввания столбцов к нижнему регистру стиль Snake case
    tmp0.columns=tmp0.columns.str.lower()
    # Заменяем пробелы на подчеркивание
    tmp0.columns = tmp0.columns.str.replace(" ", "_")

    # Вывод информации о датафрейме
    display(tmp0.head())
    print('\n' + '='*50 + '\nИнформация о DataFrame:\n' + '='*50)
    tmp0.info()
    
     # Вывод названий полей и подсчёт их типов с описанием
    count_float = 0
    count_object=0
    count_int=0
    count_datetime=0
    count_bool=0
    list_fl=[]
    list_obj=[]
    list_int=[]
    list_dt=[]
    list_bool=[]
    for col in tmp0.columns:
        if tmp0[col].dtype in ['float16', 'float32', 'float64']:
            list_fl.append(col)
            count_float += 1
        if tmp0[col].dtype in ['object']:
            list_obj.append(col)
            count_object += 1
        if tmp0[col].dtype in ['int8', 'int16', 'int32', 'int64']:
            list_int.append(col)
            count_int += 1
        if tmp0[col].dtype in ['datetime64[ns]']:
            list_dt.append(col)
            count_datetime += 1
        if tmp0[col].dtype in ['bool']:
            list_bool.append(col)
            count_bool += 1
        
    return print(f'\n Датафрейм содержит: строк - {BOLD}{tmp0.shape[0]}{RESET}, столбцов - {BOLD}{tmp0.shape[1]}{RESET} \n'
                 f'\n Названия столбцов датафрейма приведены к стилю {BOLD}snake case{RESET} \n'
                 f'\n Столбцов типа {BOLD}float{RESET}: {count_float} : {list_fl}\n' 
                 f'\n Столбцов типа {BOLD}object: {count_object}{RESET}\n : {list_obj}'
                 f'\n Столбцов типа {BOLD}int: {count_int}{RESET}\n : {list_int}'
                 f'\n Столбцов типа {BOLD}datetime: {count_datetime}{RESET} :{list_dt}'
                 f'\n Столбцов типа {BOLD}bool: {count_bool}{RESET} :{list_bool}'
                 )

# %%
show_df(df_ads_activity)
# Out:
#                               user_id ads_activity
# 0  e318-d8e69c86b543a5fb927c-c36fb6e6  очень часто
# 1  35cd-a972339dec534f49332c-a8b6d383        редко
# 2  f7e6-3b29cf9cb7ed4bb00d8f-81534360  очень редко
# 3  5186-e25a37549e50f45b2b43-178eaabe     умеренно
# 4  febd-077f277466253ee04ef6-42656680     умеренно
# ...
# Информация о DataFrame:
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5826 entries, 0 to 5825
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_id       5826 non-null   object
#  1   ads_activity  5826 non-null   object
# dtypes: object(2)
# memory usage: 91.2+ KB
#
#  Датафрейм содержит: строк - 5826, столбцов - 2
#
#  Названия столбцов датафрейма приведены к стилю snake case
#
#  Столбцов типа float: 0 : []
#
#  Столбцов типа object: 2
#  : ['user_id', 'ads_activity']
#  Столбцов типа int: 0
#  : []
#  Столбцов типа datetime: 0 :[]
#  Столбцов типа bool: 0 :[]

# %% [markdown]
# Пропусков нет

# %%
df_ads_activity.isna().sum()
# Out:
# user_id         0
# ads_activity    0
# dtype: int64

# %% [markdown]
# Нормализуем текстовые данные

# %%
# Нормализация и анализ категориальных данных
def analiz_category (tmp0, value):
    '''
    Нормализация и анализ категориальных данных
    value - список полей/поле
    tmp0 
    '''
    # нормализация
    rez=[]
    for col in value:
        tmp0[col]=tmp0[col].str.lower()
        tmp0[col]=tmp0[col].str.strip()
        rez.append(col)
    # анализ категориальных значений
    print(f'Проведена нормализация и анализ данных в {rez}: преобразованы данные к нижнему регистру, убраны лишние пробелы в начале строки и в конце строки. ')
    for column in value:
        print(f"\nColumn: {column}")
        print("\nUnique values:", tmp0[column].unique())
        print("\nUnique values count:", tmp0[column].nunique())
        print("\nMissing values count:", tmp0[column].isna().sum())
        if tmp0[column].isna().any()==True:  # есть ли хоть один пропуск
            proportion_of=tmp0[column].isna().sum()/tmp0.shape[0]
            print("\nProportion of missing values:", proportion_of)
        print("\nValue counts:\n")
        print(tmp0[column].value_counts(dropna=False), "\n")

# %%
analiz_category (df_ads_activity, ['user_id', 'ads_activity'])
# Out:
# Проведена нормализация и анализ данных в ['user_id', 'ads_activity']: преобразованы данные к нижнему регистру, убраны лишние пробелы в начале строки и в конце строки.
#
# Column: user_id
#
# Unique values: ['e318-d8e69c86b543a5fb927c-c36fb6e6' '35cd-a972339dec534f49332c-a8b6d383'
#  'f7e6-3b29cf9cb7ed4bb00d8f-81534360' ...
#  '4935-01dc73917d7e63993a53-d6c25279' '248e-badf8573d062256e2696-ccfeb267'
#  '8020-a38d1e3acfcde0832ca3-7eb07b96']
#
# Unique values count: 5593
#
# Missing values count: 0
#
# Value counts:
#
# user_id
# 5384-dc9b2024da1ed110b46d-fdffb359    2
# ee37-0689dd7ea9281f743a71-aed1b03f    2
# 4c0b-a9e74eeb12d759e172e8-b31cdb14    2
# e57a-168ea1d543c6c4b24a9e-b861493c    2
# 4906-a3aca0e6a4881849ffa1-d08c9cc1    2
#                                      ..
# 6701-8cc1d900e2d692cb8e34-bac8ef39    1
# 3e45-04cd6d5387c3d0df19ff-89cf0a91    1
# 4935-01dc73917d7e63993a53-d6c25279    1
# 248e-badf8573d062256e2696-ccfeb267    1
# 55ba-bb355dd086987f5f390f-508cb1cc    1
# ...

# %% [markdown]
# Обработка дубликатов

# %%
def obvious_duplicates(tmp0):
    """
    Функция для удаления явных дубликатов.
    """
    # Отсортируем датафрейм по всем столбцам
    df_sorted = tmp0.sort_values(by=tmp0.columns.tolist())
    # Находим дубликаты
    duplicates = df_sorted[df_sorted.duplicated(keep=False)]

    df_no_duplicated = df_sorted.drop_duplicates()
    display(f'Удалено явных дубликатов: {duplicates.shape[0]}, Число строк в датафрейме: {df_no_duplicated.shape[0]}')
    return df_no_duplicated

# %%
df_ads_activity=obvious_duplicates(df_ads_activity)

df_ads_activity.shape
# Out:
# 'Удалено явных дубликатов: 466, Число строк в датафрейме: 5593'
# (5593, 2)

# %% [markdown]
# Удалим неявные дубликаты

# %%
def implicit_duplicates(tmp0, values):
    # Отсортируем датафрейм по свем столбцам
    df_sorted3=tmp0.sort_values(by=tmp0.columns.tolist())
     # Удаляем дубликаты (1 запись удалим)
    df_no_duplicated3=df_sorted3.drop_duplicates(subset=values)
    count_df_no_duplicated3=tmp0.shape[0]-df_no_duplicated3.shape[0]
    display(f'Удалено неявных дубликатов по столбцам {values}: {count_df_no_duplicated3}')
    procent=round(1-df_no_duplicated3.shape[0]/len(df_sorted3), 3)
    print(f'доля неявных дубликатов в датафрейме {procent} ')

# %%
implicit_duplicates(df_ads_activity,['user_id', 'ads_activity'])
# Out:
# "Удалено неявных дубликатов по столбцам ['user_id', 'ads_activity']: 0"
# доля неявных дубликатов в датафрейме 0.0

# %%
df_ads_activity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5593 entries, 1472 to 2999
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_id       5593 non-null   object
#  1   ads_activity  5593 non-null   object
# dtypes: object(2)
# memory usage: 131.1+ KB

# %% [markdown]
# **df_ads_activity**
# - Датафрейм содержит: строк - 5826, столбцов - 2
# - Названия столбцов датафрейма приведены к стилю snake case
# - 2 текстовых поля
# - нормализовали
# - пропусков нет
# - дубликатов нет

# %% [markdown]
# ### `df_cloud_usage` Базовая информация о файле **df_cloud_usage.csv**

# %%
df_cloud_usage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5680 entries, 0 to 5679
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      5680 non-null   object
#  1   cloud_usage  5680 non-null   bool
# dtypes: bool(1), object(1)
# memory usage: 50.0+ KB

# %%
df_cloud_usage.head()
# Out:
#                               user_id  cloud_usage
# 0  a1e4-91c8a52eb855595e653f-298ce305        False
# 1  db9a-7b8e9e94448b7fcb19b6-4edca15f        False
# 2  0d55-9ad768879e9b08ca7ff9-843f76c7         True
# 3  4baa-43285d10a6d3cc969f2a-b21881d1        False
# 4  b8cd-cbb2411db005115ca64d-32700c62        False

# %% [markdown]
# Знакомимся с датафреймом

# %%
show_df(df_cloud_usage)
# Out:
#                               user_id  cloud_usage
# 0  a1e4-91c8a52eb855595e653f-298ce305        False
# 1  db9a-7b8e9e94448b7fcb19b6-4edca15f        False
# 2  0d55-9ad768879e9b08ca7ff9-843f76c7         True
# 3  4baa-43285d10a6d3cc969f2a-b21881d1        False
# 4  b8cd-cbb2411db005115ca64d-32700c62        False
# ...
# Информация о DataFrame:
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5680 entries, 0 to 5679
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      5680 non-null   object
#  1   cloud_usage  5680 non-null   bool
# dtypes: bool(1), object(1)
# memory usage: 50.0+ KB
#
#  Датафрейм содержит: строк - 5680, столбцов - 2
#
#  Названия столбцов датафрейма приведены к стилю snake case
#
#  Столбцов типа float: 0 : []
#
#  Столбцов типа object: 1
#  : ['user_id']
#  Столбцов типа int: 0
#  : []
#  Столбцов типа datetime: 0 :[]
#  Столбцов типа bool: 1 :['cloud_usage']

# %% [markdown]
# Пропусков нет

# %%
df_cloud_usage.isna().sum()
# Out:
# user_id        0
# cloud_usage    0
# dtype: int64

# %% [markdown]
# Нормализуем user_id

# %%
analiz_category (df_cloud_usage, ['user_id'])
# Out:
# Проведена нормализация и анализ данных в ['user_id']: преобразованы данные к нижнему регистру, убраны лишние пробелы в начале строки и в конце строки.
#
# Column: user_id
#
# Unique values: ['a1e4-91c8a52eb855595e653f-298ce305' 'db9a-7b8e9e94448b7fcb19b6-4edca15f'
#  '0d55-9ad768879e9b08ca7ff9-843f76c7' ...
#  '38ca-e9f4ad0c70aaf343ed34-4c573d57' '123c-46f5ce2c7f058cfd3e40-2bcb7c0d'
#  'b0a1-7f4332342edc93c99d85-06ca847a']
#
# Unique values count: 5680
#
# Missing values count: 0
#
# Value counts:
#
# user_id
# b0a1-7f4332342edc93c99d85-06ca847a    1
# a1e4-91c8a52eb855595e653f-298ce305    1
# db9a-7b8e9e94448b7fcb19b6-4edca15f    1
# 0d55-9ad768879e9b08ca7ff9-843f76c7    1
# 4baa-43285d10a6d3cc969f2a-b21881d1    1
#                                      ..
# 1895-988b653ac11d406ff4f9-39a39674    1
# d4d5-22b839d907d3ce957d50-51e69c6d    1
# 8f7a-049478a361f648be5c66-49f35b59    1
# b106-24bc7d759716f4b759af-766e9533    1
# fd0a-c1e99153d2917880ef76-ff1121c1    1
# ...

# %% [markdown]
# Обработка явных дубликатов

# %%
df_cloud_usage=obvious_duplicates(df_cloud_usage)

df_cloud_usage.shape
# Out:
# 'Удалено явных дубликатов: 0, Число строк в датафрейме: 5680'
# (5680, 2)

# %% [markdown]
# Поиск неявных дубликатов

# %%
implicit_duplicates(df_cloud_usage,['user_id', 'cloud_usage'])
# Out:
# "Удалено неявных дубликатов по столбцам ['user_id', 'cloud_usage']: 0"
# доля неявных дубликатов в датафрейме 0.0

# %%
df_cloud_usage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5680 entries, 5399 to 3984
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      5680 non-null   object
#  1   cloud_usage  5680 non-null   bool
# dtypes: bool(1), object(1)
# memory usage: 94.3+ KB

# %% [markdown]
# **df_cloud_usage**
# - Датафрейм содержит: строк - 5680, столбцов - 2
# - Названия столбцов датафрейма приведены к стилю snake case
# - 1 текстовое поле, 1 типа bool
# - нормализовали
# - пропусков нет
# - дубликатов нет

# %% [markdown]
# ### `df_ds_s13_users` Базовая информация о файле **df_ds_s13_users.csv**

# %%
df_ds_s13_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5913 entries, 0 to 5912
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_id       5913 non-null   object
#  1   age_category  5913 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 92.5+ KB

# %%
df_ds_s13_users.head()
# Out:
#                               user_id  age_category
# 0  f545-8c95aefe8d3e5548a689-a5b2fd39             4
# 1  cb48-5a0d6cde4d86ae10637e-c8ceb6ed             2
# 2  678b-614cd47d854b9d591db2-000b2e50             0
# 3  4ac0-dad169100b4a29b20818-b26ae7c5             4
# 4  f19b-9ac21ca973b41ecfa8c3-6a58191d             0

# %%
show_df(df_ds_s13_users)
# Out:
#                               user_id  age_category
# 0  f545-8c95aefe8d3e5548a689-a5b2fd39             4
# 1  cb48-5a0d6cde4d86ae10637e-c8ceb6ed             2
# 2  678b-614cd47d854b9d591db2-000b2e50             0
# 3  4ac0-dad169100b4a29b20818-b26ae7c5             4
# 4  f19b-9ac21ca973b41ecfa8c3-6a58191d             0
# ...
# Информация о DataFrame:
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5913 entries, 0 to 5912
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_id       5913 non-null   object
#  1   age_category  5913 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 92.5+ KB
#
#  Датафрейм содержит: строк - 5913, столбцов - 2
#
#  Названия столбцов датафрейма приведены к стилю snake case
#
#  Столбцов типа float: 0 : []
#
#  Столбцов типа object: 1
#  : ['user_id']
#  Столбцов типа int: 1
#  : ['age_category']
#  Столбцов типа datetime: 0 :[]
#  Столбцов типа bool: 0 :[]

# %%
df_ds_s13_users.isna().sum()
# Out:
# user_id         0
# age_category    0
# dtype: int64

# %%
analiz_category (df_ds_s13_users, ['user_id'])
# Out:
# Проведена нормализация и анализ данных в ['user_id']: преобразованы данные к нижнему регистру, убраны лишние пробелы в начале строки и в конце строки.
#
# Column: user_id
#
# Unique values: ['f545-8c95aefe8d3e5548a689-a5b2fd39' 'cb48-5a0d6cde4d86ae10637e-c8ceb6ed'
#  '678b-614cd47d854b9d591db2-000b2e50' ...
#  'e0d8-1b36a6b475ebfbf87c14-fa566d97' 'ad58-7c3c5b76a1dd90ba850d-0307d559'
#  'c892-72c57d41488d7956d880-3474e42b']
#
# Unique values count: 5826
#
# Missing values count: 0
#
# Value counts:
#
# user_id
# 3fb4-b0158c2fc55a76a26265-7a5c374a    2
# cda3-8ef64feb790e9e138307-173bd4ad    2
# 48c4-88e07854a9125ee372de-bef57968    2
# 05dc-feaa264cf69411853e5f-fdaf96bd    2
# 95a6-f0aeddeb9e112588bee7-4f8a50cc    2
#                                      ..
# f4bd-a23c0f510067ac3836b6-052bd910    1
# eda0-e3e82537c708854dd5f2-ec0540bf    1
# e0d8-1b36a6b475ebfbf87c14-fa566d97    1
# ad58-7c3c5b76a1dd90ba850d-0307d559    1
# c892-72c57d41488d7956d880-3474e42b    1
# ...

# %%
df_ds_s13_users=obvious_duplicates(df_ds_s13_users)

df_ds_s13_users.shape
# Out:
# 'Удалено явных дубликатов: 174, Число строк в датафрейме: 5826'
# (5826, 2)

# %%
implicit_duplicates(df_ds_s13_users,['user_id', 'age_category'])
# Out:
# "Удалено неявных дубликатов по столбцам ['user_id', 'age_category']: 0"
# доля неявных дубликатов в датафрейме 0.0

# %% [markdown]
# Понизим разрядность у числового поля

# %%
BOLD = '\033[1m'
RESET = '\033[0m'

def type_to_type(tmp0, value, to_type):
    '''
    Преобразовывает список полей в заданный тип поля с понижением разрядности,
    считает количество преобразований, пишет вывод

    tmp0 - имя датафрейма
    value - список полей, которые надо преобразовать/понизить разрядность
    to_type - тип, в который надо преобразовать поле (строка, например 'float32')
    '''
    results = []  # Для хранения сообщений о преобразованиях
    count_col = 0

    # Проверка существования колонок
    missing_cols = [col for col in value if col not in tmp0.columns]
    if missing_cols:
        print(f"Предупреждение: колонки {missing_cols} не найдены в DataFrame.")
        value = [col for col in value if col in tmp0.columns]  # Фильтруем список

    if to_type in ['float16', 'float32', 'float64', 'float']:
        for col in value:
            tmp0[col] = pd.to_numeric(tmp0[col], downcast='float')
            count_col += 1
            results.append(f'{col}')
    elif to_type in ['int16', 'int32', 'int64', 'int']:
        for col in value:
            tmp0[col] = pd.to_numeric(tmp0[col], downcast='integer')
            count_col += 1
            results.append(f'{col}')
    elif to_type in ['datetime64','datetime64[ns]', 'datetime']:
        for col in value:
            try:
                tmp0[col] = pd.to_datetime(tmp0[col])
                count_col+=1
                results.append(f'{col}')
            except ValueError as e:
                print(f'Ошибка при преобразовании {col}: {e}')

    return print('\n'.join(results), f"\n\nВсего преобразовано в {BOLD} {to_type} {RESET} с понижением разрядности {BOLD} {count_col} {RESET} полей\n")  # Возвращаем отчёт для дальнейшего использования

# %%
type_to_type(df_ds_s13_users, ['age_category'], 'int')
# Out:
# age_category
#
# Всего преобразовано в  int  с понижением разрядности  1  полей

# %%
df_ds_s13_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5826 entries, 5867 to 5842
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_id       5826 non-null   object
#  1   age_category  5826 non-null   int8
# dtypes: int8(1), object(1)
# memory usage: 96.7+ KB

# %% [markdown]
# **df_ds_s13_users**
#
# - Датафрейм содержит: строк - 5913, столбцов - 2
# - Названия столбцов датафрейма приведены к стилю snake case
# -  user_id 1 текстовое поле, 1 типа int8
# - нормализовали
# - Удалено явных дубликатов: 174, Число строк в датафрейме: 5826
# - дубликатов нет

# %% [markdown]
# ### `df_ds_s13_visits` Базовая информация о файле **df_ds_s13_visits.csv**

# %%
df_ds_s13_visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1065745 entries, 0 to 1065744
# Data columns (total 5 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   date              1065745 non-null  object
#  1   daytime           1065745 non-null  object
#  2   session_id        1065745 non-null  object
#  3   user_id           1065745 non-null  object
#  4   website_category  1065745 non-null  object
# dtypes: object(5)
# memory usage: 40.7+ MB

# %%
df_ds_s13_visits.head()
# Out:
#          date daytime                            session_id  \
# 0  2025-11-01   вечер  066e4e02-8c1f-45eb-a50f-178659abe698
# 1  2025-11-01   вечер  0bce1749-3376-439c-9a22-f8ffbba00e9a
# 2  2025-11-01   вечер  3445d8c4-221d-4d88-bb6a-a2939fe3c610
# 3  2025-11-01   вечер  3bf97286-1d91-4aaa-af4a-ed58eceb8cd2
# 4  2025-11-01   вечер  40e22712-3cad-410d-a9f0-13bd8f6911c0
#
#                               user_id website_category
# 0  0010-5cf8f6b38a7b6c70a021-009dbcda      Category 17
# 1  0010-5cf8f6b38a7b6c70a021-009dbcda      Category 19
# 2  0010-5cf8f6b38a7b6c70a021-009dbcda      Category 18
# 3  0010-5cf8f6b38a7b6c70a021-009dbcda      Category 20
# 4  0010-5cf8f6b38a7b6c70a021-009dbcda      Category 05

# %%
show_df(df_ds_s13_visits)
# Out:
#          date daytime                            session_id  \
# 0  2025-11-01   вечер  066e4e02-8c1f-45eb-a50f-178659abe698
# 1  2025-11-01   вечер  0bce1749-3376-439c-9a22-f8ffbba00e9a
# 2  2025-11-01   вечер  3445d8c4-221d-4d88-bb6a-a2939fe3c610
# 3  2025-11-01   вечер  3bf97286-1d91-4aaa-af4a-ed58eceb8cd2
# 4  2025-11-01   вечер  40e22712-3cad-410d-a9f0-13bd8f6911c0
#
#                               user_id website_category
# 0  0010-5cf8f6b38a7b6c70a021-009dbcda      Category 17
# 1  0010-5cf8f6b38a7b6c70a021-009dbcda      Category 19
# 2  0010-5cf8f6b38a7b6c70a021-009dbcda      Category 18
# 3  0010-5cf8f6b38a7b6c70a021-009dbcda      Category 20
# 4  0010-5cf8f6b38a7b6c70a021-009dbcda      Category 05
# ...
# Информация о DataFrame:
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1065745 entries, 0 to 1065744
# Data columns (total 5 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
# ...

# %%
df_ds_s13_visits.isna().sum()
# Out:
# date                0
# daytime             0
# session_id          0
# user_id             0
# website_category    0
# dtype: int64

# %%
analiz_category (df_ds_s13_visits, ['date', 'daytime', 'session_id', 'user_id', 'website_category'])
# Out:
# Проведена нормализация и анализ данных в ['date', 'daytime', 'session_id', 'user_id', 'website_category']: преобразованы данные к нижнему регистру, убраны лишние пробелы в начале строки и в конце строки.
#
# Column: date
#
# Unique values: ['2025-11-01' '2025-11-02' '2025-11-03' '2025-11-04' '2025-11-05'
#  '2025-11-06' '2025-11-07' '2025-11-08' '2025-11-09' '2025-11-10'
#  '2025-11-11' '2025-11-12' '2025-11-13' '2025-11-14']
#
# Unique values count: 14
#
# Missing values count: 0
#
# Value counts:
#
# date
# 2025-11-13    76599
# 2025-11-03    76438
# 2025-11-11    76309
# 2025-11-06    76295
# 2025-11-04    76294
# 2025-11-08    76287
# 2025-11-01    76170
# 2025-11-09    76156
# 2025-11-10    76090
# 2025-11-02    76052
# 2025-11-07    75962
# 2025-11-12    75793
# 2025-11-05    75689
# 2025-11-14    75611
# Name: count, dtype: int64
#
#
# Column: daytime
#
# Unique values: ['вечер' 'день' 'ночь' 'утро']
#
# Unique values count: 4
#
# Missing values count: 0
#
# Value counts:
#
# ...

# %%
df_ds_s13_visits=obvious_duplicates(df_ds_s13_visits)

df_ds_s13_visits.shape
# Out:
# 'Удалено явных дубликатов: 31500, Число строк в датафрейме: 1049995'
# (1049995, 5)

# %%
implicit_duplicates(df_ds_s13_visits,['date', 'daytime', 'session_id', 'user_id', 'website_category'])
# Out:
# "Удалено неявных дубликатов по столбцам ['date', 'daytime', 'session_id', 'user_id', 'website_category']: 0"
# доля неявных дубликатов в датафрейме 0.0

# %% [markdown]
# **df_ds_s13_visits**
#
# - Датафрейм содержит: строк - 1065745, столбцов - **5**
# - Названия столбцов датафрейма приведены к стилю **snake case**
# - Столбцов типа object: 5: ['date', 'daytime', 'session_id', 'user_id', 'website_category']
# - нормализовали
# - Удалено явных дубликатов: 31500, Число строк в датафрейме: 1049995
# - дубликатов неявных нет

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Изменения по комментарию, в пунктах 2.8 и 2.9:</b> Преобразование таблицы `df_ds_s13_visits`. Добавлен пункт 2.5
# </div>

# %% [markdown]
# ### Приводим таблицу `df_ds_s13_visits` к уровню **пользователя** (не сессии).
# За счет этого мы сможем сократить количество строк в таблице до 5000-6000 и сформируем новые признаки. Для этого агрегируем данные по `user_id`. Будем использовать метод `pivot_table`
#
# По сути сформируем новую таблицу, посторенную на основе `df_ds_s13_visits` с рассчитанными групповыми показателями.

# %%
df_ds_s13_visits['date'] = pd.to_datetime(df_ds_s13_visits['date'])

# %%
df_ds_s13_visits['dayweek'] = df_ds_s13_visits['date'].dt.dayofweek

# %% [markdown]
# **Построение новых признаков на основе `df_ds_s13_visits`**
#
# - доля интернет-активности пользователя приходится в зависимости от посещение  разных категорий сайтов website_category (share_of_visited_websites)
# - распределение активности пользователя во времени в процентах (share_of_daytime)
# - Среднее количество сессий пользователя в день (mean_session)
# - Наиболее активное время суток у пользователя (max_active_daytime)

# %% [markdown]
# *Долю интернет-активности пользователя в зависимости от посещениея разных категорий сайтов (`share_of_visited_websites / share_of_visited_category01 ...`)* рассчитаем как отношение *количества сессий пользователя по каждой категории* к *общему количеству сессий пользователя*

# %%
# количество посещений пользователем категории сайта
visits = pd.pivot_table(
    df_ds_s13_visits, 
    values='session_id', 
    index= 'user_id' ,
    columns='website_category', 
    aggfunc='count', 
    fill_value=0 
)

# %%
# Общее количество посещений пользователем категории сайта
count_visits = pd.pivot_table(
    df_ds_s13_visits, 
    values='session_id', 
    index= 'user_id' ,
    aggfunc='count', 
    fill_value=0
)

# %%
count_visits.rename(columns={'session_id': 'count_session_id'}, inplace=True)
count_visits.reset_index()
# Out:
#                                  user_id  count_session_id
# 0     0010-5cf8f6b38a7b6c70a021-009dbcda               546
# 1     0013-4ae5f7d127b91a3fb0f8-ba59f141               185
# 2     0014-d3032d60979a8d2b3077-f09bdce8               117
# 3     001a-eee53e44f848608779b0-78704a67               287
# 4     002c-40a064b12e1217e12207-a56eaf3b               490
# ...                                  ...               ...
# 5821  ff8f-8167e729650d17c3add4-205d9000               118
# 5822  ff92-8c8d93a642a46d347963-033140eb               346
# 5823  ffa9-44aaa5379e9d408ff0dc-0f7f6119               100
# 5824  ffab-d0fa7686828005ebbcd1-a4b28b3a               168
# 5825  ffbf-71c28263b860736010d4-a0ee88f3               244
#
# [5826 rows x 2 columns]

# %%
share_of_visited_websites = visits.div(count_visits['count_session_id'], axis=0, level='user_id').fillna(0).round(3)

# %% [markdown]
# переименуем колонки

# %%
new_columns_name=[]
for col in share_of_visited_websites.columns:
    if col == 'user_id':
        new_columns_name.append(col)
    else:
        new_columns_name.append(f'share_of_visited_{col}')

share_of_visited_websites.columns = new_columns_name

# %% [markdown]
# Сбросим индекс

# %%
share_of_visited_websites.reset_index()
# Out:
#                                  user_id  share_of_visited_category 01  \
# 0     0010-5cf8f6b38a7b6c70a021-009dbcda                         0.029
# 1     0013-4ae5f7d127b91a3fb0f8-ba59f141                         0.081
# 2     0014-d3032d60979a8d2b3077-f09bdce8                         0.009
# 3     001a-eee53e44f848608779b0-78704a67                         0.066
# 4     002c-40a064b12e1217e12207-a56eaf3b                         0.000
# ...                                  ...                           ...
# 5821  ff8f-8167e729650d17c3add4-205d9000                         0.051
# 5822  ff92-8c8d93a642a46d347963-033140eb                         0.066
# 5823  ffa9-44aaa5379e9d408ff0dc-0f7f6119                         0.020
# 5824  ffab-d0fa7686828005ebbcd1-a4b28b3a                         0.054
# 5825  ffbf-71c28263b860736010d4-a0ee88f3                         0.012
#
#       share_of_visited_category 02  share_of_visited_category 03  \
# ...

# %%
share_of_visited_websites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5826 entries, 0010-5cf8f6b38a7b6c70a021-009dbcda to ffbf-71c28263b860736010d4-a0ee88f3
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   share_of_visited_category 01  5826 non-null   float64
#  1   share_of_visited_category 02  5826 non-null   float64
#  2   share_of_visited_category 03  5826 non-null   float64
#  3   share_of_visited_category 04  5826 non-null   float64
#  4   share_of_visited_category 05  5826 non-null   float64
#  5   share_of_visited_category 06  5826 non-null   float64
#  6   share_of_visited_category 07  5826 non-null   float64
#  7   share_of_visited_category 08  5826 non-null   float64
#  8   share_of_visited_category 09  5826 non-null   float64
#  9   share_of_visited_category 10  5826 non-null   float64
#  10  share_of_visited_category 11  5826 non-null   float64
# ...

# %% [markdown]
# *Pаспределение активности пользователя во времени в процентах (share_of_daytime)*

# %%
# количество посещений пользователем во времени
daytime = pd.pivot_table(
    df_ds_s13_visits, 
    values='session_id', 
    index= 'user_id' ,
    columns='daytime', 
    aggfunc='count', 
    fill_value=0 
)

# %%
share_daytime = daytime.div(count_visits['count_session_id'], axis=0, level='user_id').fillna(0).round(3)

# %%
new_columns_name=[]
for col in share_daytime.columns:
    if col == 'user_id':
        new_columns_name.append(col)
    else:
        new_columns_name.append(f'share_daytime_{col}')

share_daytime.columns = new_columns_name

# %%
share_daytime.reset_index()
# Out:
#                                  user_id  share_daytime_вечер  \
# 0     0010-5cf8f6b38a7b6c70a021-009dbcda                0.414
# 1     0013-4ae5f7d127b91a3fb0f8-ba59f141                0.276
# 2     0014-d3032d60979a8d2b3077-f09bdce8                0.308
# 3     001a-eee53e44f848608779b0-78704a67                0.415
# 4     002c-40a064b12e1217e12207-a56eaf3b                0.296
# ...                                  ...                  ...
# 5821  ff8f-8167e729650d17c3add4-205d9000                0.449
# 5822  ff92-8c8d93a642a46d347963-033140eb                0.376
# 5823  ffa9-44aaa5379e9d408ff0dc-0f7f6119                0.380
# 5824  ffab-d0fa7686828005ebbcd1-a4b28b3a                0.310
# 5825  ffbf-71c28263b860736010d4-a0ee88f3                0.328
#
#       share_daytime_день  share_daytime_ночь  share_daytime_утро
# 0                  0.326               0.095               0.165
# 1                  0.373               0.086               0.265
# ...

# %% [markdown]
# *Среднее количество сессий пользователя в день (mean_session)*

# %%
# количество сессий пользователя за день
date = pd.pivot_table(
    df_ds_s13_visits, 
    values='session_id', 
    index= 'user_id' ,
    columns='date', 
    aggfunc='count', 
    fill_value=0
)

# %%
mean_session = date.div(count_visits['count_session_id'], axis=0, level='user_id').fillna(0).round(3)

# %%
new_columns_name=[]
for col in mean_session.columns:
    if col == 'user_id':
        new_columns_name.append(col)
    else:
        new_columns_name.append(f'mean_session_{col}')

mean_session.columns = new_columns_name

# %%
mean_session.reset_index()
# Out:
#                                  user_id  mean_session_2025-11-01 00:00:00  \
# 0     0010-5cf8f6b38a7b6c70a021-009dbcda                             0.077
# 1     0013-4ae5f7d127b91a3fb0f8-ba59f141                             0.092
# 2     0014-d3032d60979a8d2b3077-f09bdce8                             0.094
# 3     001a-eee53e44f848608779b0-78704a67                             0.084
# 4     002c-40a064b12e1217e12207-a56eaf3b                             0.071
# ...                                  ...                               ...
# 5821  ff8f-8167e729650d17c3add4-205d9000                             0.102
# 5822  ff92-8c8d93a642a46d347963-033140eb                             0.081
# 5823  ffa9-44aaa5379e9d408ff0dc-0f7f6119                             0.060
# 5824  ffab-d0fa7686828005ebbcd1-a4b28b3a                             0.083
# 5825  ffbf-71c28263b860736010d4-a0ee88f3                             0.049
#
# ...

# %% [markdown]
# *Наиболее активное время суток у пользователя (max_active_daytime)*

# %%
max_daytime = daytime.idxmax(axis=1).reset_index(name='max_active_daytime')

# %%
max_daytime.head()
# Out:
#                               user_id max_active_daytime
# 0  0010-5cf8f6b38a7b6c70a021-009dbcda              вечер
# 1  0013-4ae5f7d127b91a3fb0f8-ba59f141               день
# 2  0014-d3032d60979a8d2b3077-f09bdce8               день
# 3  001a-eee53e44f848608779b0-78704a67              вечер
# 4  002c-40a064b12e1217e12207-a56eaf3b               день

# %% [markdown]
# Итак, рассчитали на основе таблицы `df_ds_s13_visits` 4 показателя и получили много столбцов.
#
# Объединим все эти признаки и получим новую таблицу `new_df_ds_s13_visits`, в разрезе пользователя, которую затем объединим с остальными 5 таблицами и получим единый датафрейм.

# %%
list_visits_tables = [count_visits, share_daytime, mean_session, max_daytime]
new_df_ds_s13_visits = share_of_visited_websites

for tab in list_visits_tables:
    new_df_ds_s13_visits = new_df_ds_s13_visits.merge(tab, on='user_id')

# %%
new_df_ds_s13_visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5826 entries, 0 to 5825
# Data columns (total 41 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   user_id                           5826 non-null   object
#  1   share_of_visited_category 01      5826 non-null   float64
#  2   share_of_visited_category 02      5826 non-null   float64
#  3   share_of_visited_category 03      5826 non-null   float64
#  4   share_of_visited_category 04      5826 non-null   float64
#  5   share_of_visited_category 05      5826 non-null   float64
#  6   share_of_visited_category 06      5826 non-null   float64
#  7   share_of_visited_category 07      5826 non-null   float64
#  8   share_of_visited_category 08      5826 non-null   float64
#  9   share_of_visited_category 09      5826 non-null   float64
#  10  share_of_visited_category 10      5826 non-null   float64
# ...

# %% [markdown]
# ### `df_primary_device` Базовая информация о файле **df_primary_device.csv**

# %%
df_primary_device.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5669 entries, 0 to 5668
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   user_id         5669 non-null   object
#  1   primary_device  5669 non-null   object
# dtypes: object(2)
# memory usage: 88.7+ KB

# %%
df_primary_device.head()
# Out:
#                               user_id primary_device
# 0  d602-ec060db7597a6b8cd4e7-aa625896       смартфон
# 1  9204-9558455be649d4e77945-b5e25d62             ПК
# 2  5eea-22babd6a9474b43b9d0b-a39a4cf2        ноутбук
# 3  c142-0296948e8d08e417de10-2da9523c       смартфон
# 4  abec-bb4092da51eb2233a928-e44ba074             ПК

# %%
show_df(df_primary_device)
df_primary_device.isna().sum()
analiz_category (df_primary_device, ['user_id', 'primary_device'])
df_primary_device=obvious_duplicates(df_primary_device)

df_primary_device.shape
implicit_duplicates(df_primary_device,['user_id', 'primary_device'])
# Out:
#                               user_id primary_device
# 0  d602-ec060db7597a6b8cd4e7-aa625896       смартфон
# 1  9204-9558455be649d4e77945-b5e25d62             ПК
# 2  5eea-22babd6a9474b43b9d0b-a39a4cf2        ноутбук
# 3  c142-0296948e8d08e417de10-2da9523c       смартфон
# 4  abec-bb4092da51eb2233a928-e44ba074             ПК
# ...
# Информация о DataFrame:
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5669 entries, 0 to 5668
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   user_id         5669 non-null   object
#  1   primary_device  5669 non-null   object
# dtypes: object(2)
# memory usage: 88.7+ KB
#
#  Датафрейм содержит: строк - 5669, столбцов - 2
#
#  Названия столбцов датафрейма приведены к стилю snake case
#
#  Столбцов типа float: 0 : []
#
#  Столбцов типа object: 2
#  : ['user_id', 'primary_device']
#  Столбцов типа int: 0
#  : []
#  Столбцов типа datetime: 0 :[]
# ...

# %%
df_primary_device.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5669 entries, 2195 to 3094
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   user_id         5669 non-null   object
#  1   primary_device  5669 non-null   object
# dtypes: object(2)
# memory usage: 132.9+ KB

# %% [markdown]
# **df_primary_device**
#
# - Датафрейм содержит: строк - 5669, столбцов - 2
# - Названия столбцов датафрейма приведены к стилю snake case
# -  2 текстовых полей
# - нормализовали
# - дубликатов нет

# %% [markdown]
# ### `df_surf_depth` Базовая информация о файле **surf_depth.csv**

# %%
df_surf_depth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5715 entries, 0 to 5714
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     5715 non-null   object
#  1   surf_depth  5715 non-null   object
# dtypes: object(2)
# memory usage: 89.4+ KB

# %%
df_surf_depth.head()
# Out:
#                               user_id    surf_depth
# 0  f238-0c4c1e787cce311541b7-736925a0  поверхностно
# 1  9030-1b562ad80182b6dc27f1-ce811740       глубоко
# 2  22e0-7c6cadcc45e246b8688d-c43c9b23  поверхностно
# 3  9d7f-a19f10756378940a49b5-5d03e1ef  поверхностно
# 4  4233-bb5ae4b09827e5497094-1a4956af       глубоко

# %%
show_df(df_surf_depth)
df_surf_depth.isna().sum()
analiz_category (df_surf_depth, ['user_id', 'surf_depth'])
df_surf_depth=obvious_duplicates(df_surf_depth)

df_surf_depth.shape
implicit_duplicates(df_surf_depth,['user_id', 'surf_depth'])
# Out:
#                               user_id    surf_depth
# 0  f238-0c4c1e787cce311541b7-736925a0  поверхностно
# 1  9030-1b562ad80182b6dc27f1-ce811740       глубоко
# 2  22e0-7c6cadcc45e246b8688d-c43c9b23  поверхностно
# 3  9d7f-a19f10756378940a49b5-5d03e1ef  поверхностно
# 4  4233-bb5ae4b09827e5497094-1a4956af       глубоко
# ...
# Информация о DataFrame:
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5715 entries, 0 to 5714
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     5715 non-null   object
#  1   surf_depth  5715 non-null   object
# dtypes: object(2)
# memory usage: 89.4+ KB
#
#  Датафрейм содержит: строк - 5715, столбцов - 2
#
#  Названия столбцов датафрейма приведены к стилю snake case
#
#  Столбцов типа float: 0 : []
#
#  Столбцов типа object: 2
#  : ['user_id', 'surf_depth']
#  Столбцов типа int: 0
#  : []
#  Столбцов типа datetime: 0 :[]
#  Столбцов типа bool: 0 :[]
# ...

# %%
df_surf_depth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5715 entries, 5068 to 4883
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     5715 non-null   object
#  1   surf_depth  5715 non-null   object
# dtypes: object(2)
# memory usage: 133.9+ KB

# %% [markdown]
#  **df_surf_depth**
#
# - Датафрейм содержит: строк - 5715, столбцов - 2
# - Названия столбцов датафрейма приведены к стилю snake case
# -  2 текстовых поля
# - нормализовали
# - дубликатов неявных нет

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> По каждому файлу проведена содержательная проверка: типы данных, явные/неявные дубликаты, нормализация категорий, понижение разрядности. Хорошо, что это оформлено переиспользуемыми функциями.
# </div>

# %% [markdown]
# ### Подготовка единого датафрейма
#
# Задача проекта предполагает создание портрета пользователя для анализа его поведения и определении категории возраста. Поэтому можно соединить данные о том, как пользователи пользуются сервисами из таблиц:
# - users (ds_s13_users.csv)
# - visits (new_df_ds_s13_visits.csv) посещения польз
# - ads_activity (ads_activity.csv) активность пользователя
# - surf_depth (surf_depth.csv) глубина погружения в сервис
# - primary_device (primary_device.csv) тип устройства
# - cloud_usage (cloud_usage.csv) работа в облаке
#
#
# Каждая строка в этих датафреймах — это информация о пользователе, поэтому такие данные удобно соединить в один датафрейм, который можно использовать для поиска закономерностей в данных. Соединять данные будем по идентификатору клиента. При соединении оставим только полные данные — это значит, что значение `user_id` пользователя должно быть в двух датафреймах.
#
# Соединим данные, используя значение параметра `how` по умолчанию — `'outer'` (полное объединение). Это позволит объединить все данные по клиентам банка. Если значение отсутствует, то подставится значение `Nan`

# %% [markdown]
# +**df_ads_activity**
# Index: 5593 entries, 1472 to 2999
# Data columns (total 2 columns):
#     Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_id       5593 non-null   object
#  1   ads_activity  5593 non-null   object
# dtypes: object(2)
# _____________
#
# +**df_cloud_usage**
# Index: 5680 entries, 5399 to 3984
# Data columns (total 2 columns):
#     Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      5680 non-null   object
#  1   cloud_usage  5680 non-null   bool
# dtypes: bool(1), object(1)
# ____________
# +**df_ds_s13_users**
# Index: 5826 entries, 5867 to 5842
# Data columns (total 2 columns):
#    Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_id       5826 non-null   object
#  1   age_category  5826 non-null   int8
#
# ________
# +**new_df_ds_s13_visits**
# RangeIndex: 5826 entries, 0 to 5825
# Data columns (total 40 columns):
# _______
#
# +**df_primary_device**
# Index: 5669 entries, 2195 to 3094
# Data columns (total 2 columns):
#     Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   user_id         5669 non-null   object
#  1   primary_device  5669 non-null   object
#
# +**df_surf_depth**
# Index: 5715 entries, 5068 to 4883
# Data columns (total 2 columns):
#     Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     5715 non-null   object
#  1   surf_depth  5715 non-null   object

# %% [markdown]
# **Объединим по очереди все датафреймы**

# %%
# Соединяем данные в единый датафрейм df
# df1 = df_ds_s13_users.merge(df_cloud_usage, on='user_id')

# %%
#df2=df1.merge(df_ads_activity, on='user_id')

# %%
#df3= df2.merge(df_primary_device, on='user_id')

# %%
#df4= df3.merge(df_surf_depth, on='user_id')

# %%
#df= df4.merge(df_ds_s13_visits, on='user_id')

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ошибка:</b> Объединение таблиц сделано через <code>merge(..., on='user_id')</code> с <code>how='inner'</code> (по умолчанию). Это создаёт две проблемы:
#
# 1. Так как `visits` содержит много строк на одного пользователя (сессии), итоговый `df` получается на уровне <b>сессии</b> (939 148 строк), а не пользователя (~5800 уникальных). Задача — классификация пользователей, значит признаковое пространство должно содержать одну строку на пользователя.
# 2. `inner join` полностью удаляет пользователей, у которых нет записи хотя бы в одной вспомогательной таблице — поэтому далее в EDA получен вывод "пропусков нет", хотя на самом деле пропуски были, просто удалены вместе со строками. Модель должна уметь работать с пользователями с пропусками (через импутацию), а не терять их.
#
# Эта же ошибка повторяется в функции `merge_df`, готовящей признаки для продакшена — то есть в проде пользователи с любым отсутствующим признаком просто не получат предсказания.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b> Спасибо, Люман! Хитрая идея, я об этом не подумала, переделываю полностью ...
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Изменения:</b>
#
# 1. Создан новый раздел 2.5 "Преобразование таблицы **df_ds_s13_visits** "
# 2. В этом (текущем) разделе заново проведу объединение таблиц. Чтобы объединить все записи с пользователями укажу тип объединения `how='outer'`
# </div>

# %%
df= new_df_ds_s13_visits.merge(df_cloud_usage, on='user_id', how='left')

# %%
four_tables = [df_ds_s13_users, df_ads_activity, df_primary_device, df_surf_depth]

# %%
for tab in four_tables:
    df= df.merge(tab, on='user_id', how='left')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5826 entries, 0 to 5825
# Data columns (total 46 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   user_id                           5826 non-null   object
#  1   share_of_visited_category 01      5826 non-null   float64
#  2   share_of_visited_category 02      5826 non-null   float64
#  3   share_of_visited_category 03      5826 non-null   float64
#  4   share_of_visited_category 04      5826 non-null   float64
#  5   share_of_visited_category 05      5826 non-null   float64
#  6   share_of_visited_category 06      5826 non-null   float64
#  7   share_of_visited_category 07      5826 non-null   float64
#  8   share_of_visited_category 08      5826 non-null   float64
#  9   share_of_visited_category 09      5826 non-null   float64
#  10  share_of_visited_category 10      5826 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['user_id', 'share_of_visited_category 01',
#        'share_of_visited_category 02', 'share_of_visited_category 03',
#        'share_of_visited_category 04', 'share_of_visited_category 05',
#        'share_of_visited_category 06', 'share_of_visited_category 07',
#        'share_of_visited_category 08', 'share_of_visited_category 09',
#        'share_of_visited_category 10', 'share_of_visited_category 11',
#        'share_of_visited_category 12', 'share_of_visited_category 13',
#        'share_of_visited_category 14', 'share_of_visited_category 15',
#        'share_of_visited_category 16', 'share_of_visited_category 17',
#        'share_of_visited_category 18', 'share_of_visited_category 19',
#        'share_of_visited_category 20', 'count_session_id',
#        'share_daytime_вечер', 'share_daytime_день', 'share_daytime_ночь',
#        'share_daytime_утро', 'mean_session_2025-11-01 00:00:00',
#        'mean_session_2025-11-02 00:00:00', 'mean_session_2025-11-03 00:00:00',
# ...

# %%
df.head()
# Out:
#                               user_id  share_of_visited_category 01  \
# 0  0010-5cf8f6b38a7b6c70a021-009dbcda                         0.029
# 1  0013-4ae5f7d127b91a3fb0f8-ba59f141                         0.081
# 2  0014-d3032d60979a8d2b3077-f09bdce8                         0.009
# 3  001a-eee53e44f848608779b0-78704a67                         0.066
# 4  002c-40a064b12e1217e12207-a56eaf3b                         0.000
#
#    share_of_visited_category 02  share_of_visited_category 03  \
# 0                         0.000                         0.062
# 1                         0.059                         0.027
# 2                         0.017                         0.034
# 3                         0.045                         0.035
# 4                         0.053                         0.071
#
#    share_of_visited_category 04  share_of_visited_category 05  \
# 0                         0.042                         0.033
# ...

# %% [markdown]
# ### Создаём новые признаки в объединённом датафрейме **df** по п.6

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b> Спасибо, полностью переделываю новые признаки (п. 2.9) в соответствии с твоим комментарием в конце раздела. Набор показателей изменим под текущие условия и таблицы.
# </div>

# %% [markdown]
# 'count_session_id' - количество сессий пользователя

# %% [markdown]
# **share_of_visited_websites** - Доля интернет-активности пользователя в общей посещаемости сайтов пользователями. Рассчитаем как отношение количества всех посещений пользователя  к общему количеству всех сессий, на 1000 пользователей

# %%
df['share_of_visited_websites'] = df['count_session_id'] / df['count_session_id'].sum()*1000

# %%
df['share_of_visited_websites']
# Out:
# 0       0.520002
# 1       0.176191
# 2       0.111429
# 3       0.273335
# 4       0.466669
#           ...
# 5821    0.112381
# 5822    0.329525
# 5823    0.095239
# 5824    0.160001
# 5825    0.232382
# Name: share_of_visited_websites, Length: 5826, dtype: float64

# %% [markdown]
# **share_of_user_clicks** - индекс кликабельности пользователя в зависимости от категории ads_activity, на 1000 кликов

# %% [markdown]
# Считаем:
# - количество кликов пользователя в звисимости от категории ads_activity (1 клик)
# - число кликов пользователей в зависимости от категории ads_activity на 1000 кликов

# %%
count_ads_activity_user=df.groupby(['ads_activity', 'user_id'])['user_id'].count()

share_of_user_clicks=((count_ads_activity_user/df.groupby(['ads_activity'])['user_id'].count())*1000).reset_index(name='share_of_user_clicks')
share_of_user_clicks
# Out:
#      ads_activity                             user_id  share_of_user_clicks
# 0     очень редко  0014-d3032d60979a8d2b3077-f09bdce8              1.189061
# 1     очень редко  001a-eee53e44f848608779b0-78704a67              1.189061
# 2     очень редко  0103-7899a2cb25e657e9e4d4-ff31a939              1.189061
# 3     очень редко  010b-ff2cede1e3bff4b74f96-b51b9ef7              1.189061
# 4     очень редко  012f-c5416db6191a72ec734f-f0bb3c84              1.189061
# ...           ...                                 ...                   ...
# 5588        часто  ff28-66345e798746304fc860-b8d30e43              0.935454
# 5589        часто  ff3a-3524daebf47ebb668982-4aac9bbe              0.935454
# 5590        часто  ff8d-7f887e5eb53bb75f5377-32b69238              0.935454
# 5591        часто  ff92-8c8d93a642a46d347963-033140eb              0.935454
# 5592        часто  ffa9-44aaa5379e9d408ff0dc-0f7f6119              0.935454
#
# [5593 rows x 3 columns]

# %% [markdown]
# объединяем **share_of_user_clicks** с датафреймом **df**

# %%
df = df.merge(share_of_user_clicks, on=['ads_activity', 'user_id'], how='left')

# %%
df['share_of_user_clicks'].nunique()
# Out:
# 5

# %% [markdown]
# **share_of_user_devices** - доля видов устройств на пользователя по primary_device, на 1000 устройств

# %%
# Количество устройств в каждой категории primary_device
count_primary_device=df.groupby(['primary_device'])['user_id'].count()
count_primary_device
# Out:
# primary_device
# ноутбук      923
# пк          1275
# планшет      388
# смартфон    3083
# Name: user_id, dtype: int64

# %%
#сколько раз с какого устройства пользователь заходил
count_primary_device_user=df.groupby(['primary_device', 'user_id'])['age_category'].count()
count_primary_device_user

#доля видов устройств на пользователя по primary_device на 1000 устройств
share_of_user_devices=((count_primary_device_user/count_primary_device)*1000).reset_index(name='share_of_user_devices')
share_of_user_devices

df = df.merge(share_of_user_devices, on=['primary_device', 'user_id'], how='left')

# %%
df.head()
# Out:
#                               user_id  share_of_visited_category 01  \
# 0  0010-5cf8f6b38a7b6c70a021-009dbcda                         0.029
# 1  0013-4ae5f7d127b91a3fb0f8-ba59f141                         0.081
# 2  0014-d3032d60979a8d2b3077-f09bdce8                         0.009
# 3  001a-eee53e44f848608779b0-78704a67                         0.066
# 4  002c-40a064b12e1217e12207-a56eaf3b                         0.000
#
#    share_of_visited_category 02  share_of_visited_category 03  \
# 0                         0.000                         0.062
# 1                         0.059                         0.027
# 2                         0.017                         0.034
# 3                         0.045                         0.035
# 4                         0.053                         0.071
#
#    share_of_visited_category 04  share_of_visited_category 05  \
# 0                         0.042                         0.033
# ...

# %%
df['share_of_user_devices'].nunique()
# Out:
# 4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5826 entries, 0 to 5825
# Data columns (total 49 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   user_id                           5826 non-null   object
#  1   share_of_visited_category 01      5826 non-null   float64
#  2   share_of_visited_category 02      5826 non-null   float64
#  3   share_of_visited_category 03      5826 non-null   float64
#  4   share_of_visited_category 04      5826 non-null   float64
#  5   share_of_visited_category 05      5826 non-null   float64
#  6   share_of_visited_category 06      5826 non-null   float64
#  7   share_of_visited_category 07      5826 non-null   float64
#  8   share_of_visited_category 08      5826 non-null   float64
#  9   share_of_visited_category 09      5826 non-null   float64
#  10  share_of_visited_category 10      5826 non-null   float64
# ...

# %% [markdown]
# Рассчитаем обобщенный показатель активности пользователя **users_activity**: перемножим `'age_category'` (возрастная категория), `'share_of_user_clicks'` (доля интенсивности кликов пользователя в зависимости от категории ads_activity), `'share_of_user_devices'` , `'share_of_visited_websites'`.

# %%
df['users_activity'] = (df['age_category']*df['share_of_user_clicks']*df['share_of_user_devices'] * df['share_of_visited_websites']).round(3)

# %%
df['users_activity'].nunique()
# Out:
# 847

# %% [markdown]
# **Преобразование типа поля `cloud_usage`**

# %% [markdown]
# Преобразуем поле `cloud_usage` в числовое. Для этого используем astype.

# %%
most_frequent = df['cloud_usage'].mode().iloc[0]
df['cloud_usage'] = df['cloud_usage'].fillna(most_frequent)
# Out:
# C:\Users\eakon\AppData\Local\Temp\ipykernel_22772\3119325325.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['cloud_usage'] = df['cloud_usage'].fillna(most_frequent)

# %%
df['cloud_usage']=df['cloud_usage'].astype(int)

# %%
# распределение пользователей по возрасту для 'users_activity', 'cloud_usage'
sum_age_category = pd.pivot_table(
    df, 
    values= ['users_activity', 'cloud_usage'],
    index= 'user_id',
    columns='age_category',
    aggfunc='sum', 
    fill_value=0
   
)

# %% [markdown]
# Переименуем стоблцы датафрейма

# %%
sum_age_category.columns
new_col=[]
i=0
j=0
for col in sum_age_category.columns:
    if 'cloud_usage' in col:
        new_col.append(f'cloud_usage_{i}')
        i=i+1
    else:
        new_col.append(f'users_activity_{j}')
        j=j+1 

sum_age_category.columns=new_col

# %%
sum_age_category.head()
# Out:
#                                     cloud_usage_0  cloud_usage_1  \
# user_id
# 0010-5cf8f6b38a7b6c70a021-009dbcda              1              0
# 0013-4ae5f7d127b91a3fb0f8-ba59f141              0              0
# 0014-d3032d60979a8d2b3077-f09bdce8              0              0
# 001a-eee53e44f848608779b0-78704a67              0              0
# 002c-40a064b12e1217e12207-a56eaf3b              0              0
#
#                                     cloud_usage_2  cloud_usage_3  \
# user_id
# 0010-5cf8f6b38a7b6c70a021-009dbcda              0              0
# 0013-4ae5f7d127b91a3fb0f8-ba59f141              0              0
# 0014-d3032d60979a8d2b3077-f09bdce8              0              0
# 001a-eee53e44f848608779b0-78704a67              0              0
# 002c-40a064b12e1217e12207-a56eaf3b              0              0
#
#                                     cloud_usage_4  users_activity_0  \
# user_id
# 0010-5cf8f6b38a7b6c70a021-009dbcda              0               0.0
# ...

# %% [markdown]
# **character_age0**, **character_age1**,	**character_age2**,	**character_age3**,	**character_age4** - обобщающие показатели, характеризующие деятельность пользователя (основные характеристики и использование облаков) в зависимости от возраста
#
# Суммируем cloud_usage и users_activity для своего возраста и делим на количество

# %%
for i in range(5):
    sum_age_category[f'age{i}'] = (sum_age_category[f'cloud_usage_{i}'] + sum_age_category[f'users_activity_{i}'])
    sum_age_category[f'character_age{i}'] = (sum_age_category[f'age{i}']/sum_age_category[f'age{i}'].sum()*1000).round(3)

# %%
sum_age_category.head()
# Out:
#                                     cloud_usage_0  cloud_usage_1  \
# user_id
# 0010-5cf8f6b38a7b6c70a021-009dbcda              1              0
# 0013-4ae5f7d127b91a3fb0f8-ba59f141              0              0
# 0014-d3032d60979a8d2b3077-f09bdce8              0              0
# 001a-eee53e44f848608779b0-78704a67              0              0
# 002c-40a064b12e1217e12207-a56eaf3b              0              0
#
#                                     cloud_usage_2  cloud_usage_3  \
# user_id
# 0010-5cf8f6b38a7b6c70a021-009dbcda              0              0
# 0013-4ae5f7d127b91a3fb0f8-ba59f141              0              0
# 0014-d3032d60979a8d2b3077-f09bdce8              0              0
# 001a-eee53e44f848608779b0-78704a67              0              0
# 002c-40a064b12e1217e12207-a56eaf3b              0              0
#
#                                     cloud_usage_4  users_activity_0  \
# user_id
# 0010-5cf8f6b38a7b6c70a021-009dbcda              0               0.0
# ...

# %% [markdown]
# Присоединим **character_age0**, **character_age1**,	**character_age2**,	**character_age3**,	**character_age4**  к датафрейму **df**

# %%
add_colls = ['character_age0',
       'character_age1', 'character_age2', 'character_age3', 'character_age4']
df=df.merge(sum_age_category[add_colls], on='user_id', how='left')

# %% [markdown]
# **character_ctr0**, **character_ctr1**,	**character_ctr2**,	**character_ctr3**,	**character_ctr4** - обобщающие показатели, характеризующие деятельность пользователя (основные характеристики и использование облаков) в зависимости от CTR

# %%
# распределение пользователей по кликабельности CTR ('ads_activity') для 'users_activity', 'cloud_usage'
sum_ads_activity = pd.pivot_table(
    df, 
    values= ['users_activity', 'cloud_usage'],
    index= 'user_id',
    columns='ads_activity',
    aggfunc='sum', 
    fill_value=0
)

# %%
i=0
j=0
new_col2=[]
for col in sum_ads_activity.columns:
    if 'cloud_usage' in col:
        new_col2.append(f'cloud_usage_{i}')
        i=i+1
    else:
        new_col2.append(f'users_activity_{j}')
        j=j+1 

sum_ads_activity.columns=new_col2

# %% [markdown]
# Рассчитаем показатели character_ctr0, character_ctr1, character_ctr2, character_ctr3, character_ctr4

# %%
for i in range(5):
    sum_ads_activity[f'ctr{i}'] = (sum_ads_activity[f'cloud_usage_{i}'] + sum_ads_activity[f'users_activity_{i}'])
    sum_ads_activity[f'character_ctr{i}'] = (sum_ads_activity[f'ctr{i}']/sum_ads_activity[f'ctr{i}'].sum()*1000).round(3)

# %% [markdown]
# Объединяем с df

# %%
add_colls2 = ['character_ctr0','character_ctr1','character_ctr2',
              'character_ctr3','character_ctr4']
df=df.merge(sum_ads_activity[add_colls2], on='user_id', how='left')

# %% [markdown]
# Рассчитаем **11** столбцов, характеризующих пользователя: `share_of_user_clicks, share_of_user_devices, users_activity, character_age0, character_age1,	character_age2,	character_age3,	character_age4, character_ctr0, character_ctr1,	character_ctr2,	character_ctr3,	character_ctr4`
#
# - **share_of_user_clicks** - индекс кликабельности пользователя в зависимости от категории ads_activity, на 1000 кликов
# - **share_of_user_devices** - доля видов устройств на пользователя по primary_device, на 1000 устройств
#
# - **users_activity** -  обобщенный показатель активности пользователя: перемножим `'age_category'` (возрастная категория), `'share_of_user_clicks'` (доля интенсивности кликов пользователя в зависимости от категории ads_activity), `'share_of_user_devices'` , `'share_of_visited_websites'`
#
# - **character_age0**, **character_age1**,	**character_age2**,	**character_age3**,	**character_age4** - обобщающие показатели, характеризующие деятельность пользователя (основные характеристики и использование облаков) в зависимости от возраста
#
# - **character_ctr0**, **character_ctr1**,	**character_ctr2**,	**character_ctr3**,	**character_ctr4** - обобщающие показатели, характеризующие деятельность пользователя (основные характеристики и использование облаков) в зависимости от CTR

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5826 entries, 0 to 5825
# Data columns (total 60 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   user_id                           5826 non-null   object
#  1   share_of_visited_category 01      5826 non-null   float64
#  2   share_of_visited_category 02      5826 non-null   float64
#  3   share_of_visited_category 03      5826 non-null   float64
#  4   share_of_visited_category 04      5826 non-null   float64
#  5   share_of_visited_category 05      5826 non-null   float64
#  6   share_of_visited_category 06      5826 non-null   float64
#  7   share_of_visited_category 07      5826 non-null   float64
#  8   share_of_visited_category 08      5826 non-null   float64
#  9   share_of_visited_category 09      5826 non-null   float64
#  10  share_of_visited_category 10      5826 non-null   float64
# ...

# %% [markdown]
# ###### Таким образом, рассчитано и добавлено в датафрейм **df** 11 показателей:
# - **share_of_user_clicks** - индекс кликабельности пользователя в зависимости от категории ads_activity, на 1000 кликов
# - **share_of_user_devices** - доля видов устройств на пользователя по primary_device, на 1000 устройств
#
# - **users_activity** -  обобщенный показатель активности пользователя: перемножим `'age_category'` (возрастная категория), `'share_of_user_clicks'` (доля интенсивности кликов пользователя в зависимости от категории ads_activity), `'share_of_user_devices'` , `'share_of_visited_websites'`
#
# - **character_age0**, **character_age1**,	**character_age2**,	**character_age3**,	**character_age4** - обобщающие показатели, характеризующие деятельность пользователя (основные характеристики и использование облаков) в зависимости от возраста
#
# - **character_ctr0**, **character_ctr1**,	**character_ctr2**,	**character_ctr3**,	**character_ctr4** - обобщающие показатели, характеризующие деятельность пользователя (основные характеристики и использование облаков) в зависимости от CTR
#
# Ha этапе 2.5, по таблице **df_ds_s13_visits** рассчитано 4 признака, которые также попали в результате объединения, в датафрейм **df**:
# - доля интернет-активности пользователя приходится в зависимости от посещение  разных категорий сайтов website_category (`share_of_visited_websites`)
# - распределение активности пользователя во времени в процентах (`share_of_daytime`)
# - Среднее количество сессий пользователя в день (`mean_session`)
# - Наиболее активное время суток у пользователя (`max_active_daytime`)
#
# Таким образом, всего рассчитано и добавлено 15 показателей.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ошибка:</b> Идей по признакам много и они разнообразны (доли посещений, интенсивность кликов, устройства, "вес аудитории" и т.д.) — это хорошая инициатива, но они считаются на датафрейме на уровне сессий, а не пользователей (см. предыдущий комментарий). Нужно сначала агрегировать признаки по <code>user_id</code> до одной строки на пользователя, и только потом объединять их в единый датафрейм. Как следствие текущего подхода, обучающая выборка "раздувается" до сотен тысяч строк, что далее вынуждает обучать финальную модель на выборке всего 11 237 записей (2% от train) вместо всех доступных данных.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b> Сделано
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Изменения:</b> Полностью переделаны пункты 2.5 и 2.9. Старые признаки не подходили, пришлось сочинять новые, повозилась немного. Теперь все данные представлены на уровне пользователей, около 5800 записей в датафрейме.
#
# Описание тоже изменено под новые расчеты.
# </div>

# %% [markdown]
# ### Изучим новый датафрейм df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5826 entries, 0 to 5825
# Data columns (total 60 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   user_id                           5826 non-null   object
#  1   share_of_visited_category 01      5826 non-null   float64
#  2   share_of_visited_category 02      5826 non-null   float64
#  3   share_of_visited_category 03      5826 non-null   float64
#  4   share_of_visited_category 04      5826 non-null   float64
#  5   share_of_visited_category 05      5826 non-null   float64
#  6   share_of_visited_category 06      5826 non-null   float64
#  7   share_of_visited_category 07      5826 non-null   float64
#  8   share_of_visited_category 08      5826 non-null   float64
#  9   share_of_visited_category 09      5826 non-null   float64
#  10  share_of_visited_category 10      5826 non-null   float64
# ...

# %%
df.head()
# Out:
#                               user_id  share_of_visited_category 01  \
# 0  0010-5cf8f6b38a7b6c70a021-009dbcda                         0.029
# 1  0013-4ae5f7d127b91a3fb0f8-ba59f141                         0.081
# 2  0014-d3032d60979a8d2b3077-f09bdce8                         0.009
# 3  001a-eee53e44f848608779b0-78704a67                         0.066
# 4  002c-40a064b12e1217e12207-a56eaf3b                         0.000
#
#    share_of_visited_category 02  share_of_visited_category 03  \
# 0                         0.000                         0.062
# 1                         0.059                         0.027
# 2                         0.017                         0.034
# 3                         0.045                         0.035
# 4                         0.053                         0.071
#
#    share_of_visited_category 04  share_of_visited_category 05  \
# 0                         0.042                         0.033
# ...

# %%
show_df(df)
# Out:
#                               user_id  share_of_visited_category_01  \
# 0  0010-5cf8f6b38a7b6c70a021-009dbcda                         0.029
# 1  0013-4ae5f7d127b91a3fb0f8-ba59f141                         0.081
# 2  0014-d3032d60979a8d2b3077-f09bdce8                         0.009
# 3  001a-eee53e44f848608779b0-78704a67                         0.066
# 4  002c-40a064b12e1217e12207-a56eaf3b                         0.000
#
#    share_of_visited_category_02  share_of_visited_category_03  \
# 0                         0.000                         0.062
# 1                         0.059                         0.027
# 2                         0.017                         0.034
# 3                         0.045                         0.035
# 4                         0.053                         0.071
#
#    share_of_visited_category_04  share_of_visited_category_05  \
# 0                         0.042                         0.033
# ...

# %%
df.isna().sum()
# Out:
# user_id                               0
# share_of_visited_category_01          0
# share_of_visited_category_02          0
# share_of_visited_category_03          0
# share_of_visited_category_04          0
# share_of_visited_category_05          0
# share_of_visited_category_06          0
# share_of_visited_category_07          0
# share_of_visited_category_08          0
# share_of_visited_category_09          0
# share_of_visited_category_10          0
# share_of_visited_category_11          0
# share_of_visited_category_12          0
# share_of_visited_category_13          0
# share_of_visited_category_14          0
# share_of_visited_category_15          0
# share_of_visited_category_16          0
# share_of_visited_category_17          0
# share_of_visited_category_18          0
# share_of_visited_category_19          0
# share_of_visited_category_20          0
# count_session_id                      0
# share_daytime_вечер                   0
# ...

# %% [markdown]
# Заменим пропуски

# %%
col_float =['share_of_user_clicks', 'share_of_user_devices', 'users_activity']

for col in col_float:
    mean = df[col].mean()
    df[col] = df[col].fillna(mean)

# %%
col_object =['cloud_usage', 'ads_activity', 'primary_device', 'surf_depth']

for col in col_object:
    most_frequent = df[col].mode().iloc[0]
    df[col] = df[col].fillna(most_frequent)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5826 entries, 0 to 5825
# Data columns (total 60 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   user_id                           5826 non-null   object
#  1   share_of_visited_category_01      5826 non-null   float64
#  2   share_of_visited_category_02      5826 non-null   float64
#  3   share_of_visited_category_03      5826 non-null   float64
#  4   share_of_visited_category_04      5826 non-null   float64
#  5   share_of_visited_category_05      5826 non-null   float64
#  6   share_of_visited_category_06      5826 non-null   float64
#  7   share_of_visited_category_07      5826 non-null   float64
#  8   share_of_visited_category_08      5826 non-null   float64
#  9   share_of_visited_category_09      5826 non-null   float64
#  10  share_of_visited_category_10      5826 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['user_id', 'share_of_visited_category_01',
#        'share_of_visited_category_02', 'share_of_visited_category_03',
#        'share_of_visited_category_04', 'share_of_visited_category_05',
#        'share_of_visited_category_06', 'share_of_visited_category_07',
#        'share_of_visited_category_08', 'share_of_visited_category_09',
#        'share_of_visited_category_10', 'share_of_visited_category_11',
#        'share_of_visited_category_12', 'share_of_visited_category_13',
#        'share_of_visited_category_14', 'share_of_visited_category_15',
#        'share_of_visited_category_16', 'share_of_visited_category_17',
#        'share_of_visited_category_18', 'share_of_visited_category_19',
#        'share_of_visited_category_20', 'count_session_id',
#        'share_daytime_вечер', 'share_daytime_день', 'share_daytime_ночь',
#        'share_daytime_утро', 'mean_session_2025-11-01_00:00:00',
#        'mean_session_2025-11-02_00:00:00', 'mean_session_2025-11-03_00:00:00',
# ...

# %%
analiz_category (df, ['max_active_daytime', 'ads_activity', 'primary_device', 'surf_depth'])
# Out:
# Проведена нормализация и анализ данных в ['max_active_daytime', 'ads_activity', 'primary_device', 'surf_depth']: преобразованы данные к нижнему регистру, убраны лишние пробелы в начале строки и в конце строки.
#
# Column: max_active_daytime
#
# Unique values: ['вечер' 'день' 'утро']
#
# Unique values count: 3
#
# Missing values count: 0
#
# Value counts:
#
# max_active_daytime
# день     3087
# вечер    2735
# утро        4
# Name: count, dtype: int64
#
#
# Column: ads_activity
#
# Unique values: ['умеренно' 'очень редко' 'часто' 'редко' 'очень часто']
#
# Unique values count: 5
#
# Missing values count: 0
#
# Value counts:
#
# ads_activity
# умеренно       2057
# редко          1634
# часто          1069
# очень редко     841
# очень часто     225
# Name: count, dtype: int64
#
#
# Column: primary_device
#
# Unique values: ['ноутбук' 'планшет' 'смартфон' 'пк']
#
# Unique values count: 4
#
# Missing values count: 0
#
# Value counts:
#
# primary_device
# смартфон    3240
# ...

# %%
df=obvious_duplicates(df)

df.shape
# Out:
# 'Удалено явных дубликатов: 0, Число строк в датафрейме: 5826'
# (5826, 60)

# %%
implicit_duplicates(df,['user_id', 'age_category', 'cloud_usage', 'ads_activity',
       'primary_device', 'surf_depth'])
# Out:
# "Удалено неявных дубликатов по столбцам ['user_id', 'age_category', 'cloud_usage', 'ads_activity', 'primary_device', 'surf_depth']: 0"
# доля неявных дубликатов в датафрейме 0.0

# %% [markdown]
# Понизим разрядность `cloud_usage` с **int64** до **int8**

# %%
numeric_float = ['cloud_usage', 'share_of_visited_category_01',
       'share_of_visited_category_02', 'share_of_visited_category_03',
       'share_of_visited_category_04', 'share_of_visited_category_05',
       'share_of_visited_category_06', 'share_of_visited_category_07',
       'share_of_visited_category_08', 'share_of_visited_category_09',
       'share_of_visited_category_10', 'share_of_visited_category_11',
       'share_of_visited_category_12', 'share_of_visited_category_13',
       'share_of_visited_category_14', 'share_of_visited_category_15',
       'share_of_visited_category_16', 'share_of_visited_category_17',
       'share_of_visited_category_18', 'share_of_visited_category_19',
       'share_of_visited_category_20', 'share_daytime_вечер',
       'share_daytime_день', 'share_daytime_ночь', 'share_daytime_утро',
       'mean_session_2025-11-01_00:00:00', 'mean_session_2025-11-02_00:00:00',
       'mean_session_2025-11-03_00:00:00', 'mean_session_2025-11-04_00:00:00',
       'mean_session_2025-11-05_00:00:00', 'mean_session_2025-11-06_00:00:00',
       'mean_session_2025-11-07_00:00:00', 'mean_session_2025-11-08_00:00:00',
       'mean_session_2025-11-09_00:00:00', 'mean_session_2025-11-10_00:00:00',
       'mean_session_2025-11-11_00:00:00', 'mean_session_2025-11-12_00:00:00',
       'mean_session_2025-11-13_00:00:00', 'mean_session_2025-11-14_00:00:00', 
        'share_of_visited_websites', 'share_of_user_clicks',
       'share_of_user_devices', 'users_activity',
       'character_age0', 'character_age1', 'character_age2',
       'character_age3', 'character_age4', 'character_ctr0', 'character_ctr1',
       'character_ctr2', 'character_ctr3', 'character_ctr4']
numeric_int = ['age_category']

# %%
for col in numeric_int:
    df[col]=pd.to_numeric(df[col], downcast='integer')

# %%
for col in numeric_float:
    df[col]=pd.to_numeric(df[col], downcast='float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5826 entries, 0 to 5825
# Data columns (total 60 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   user_id                           5826 non-null   object
#  1   share_of_visited_category_01      5826 non-null   float32
#  2   share_of_visited_category_02      5826 non-null   float32
#  3   share_of_visited_category_03      5826 non-null   float32
#  4   share_of_visited_category_04      5826 non-null   float32
#  5   share_of_visited_category_05      5826 non-null   float32
#  6   share_of_visited_category_06      5826 non-null   float32
#  7   share_of_visited_category_07      5826 non-null   float32
#  8   share_of_visited_category_08      5826 non-null   float32
#  9   share_of_visited_category_09      5826 non-null   float32
#  10  share_of_visited_category_10      5826 non-null   float32
# ...

# %% [markdown]
# **df**
#
# - Датафрейм содержит: строк - **939148**, столбцов - **60**
#
#  Названия столбцов датафрейма приведены к стилю **snake case**
#
#  Столбцов типа **float: 52** : ['share_of_visited_category_01', 'share_of_visited_category_02', 'share_of_visited_category_03', 'share_of_visited_category_04', 'share_of_visited_category_05', 'share_of_visited_category_06', 'share_of_visited_category_07', 'share_of_visited_category_08', 'share_of_visited_category_09', 'share_of_visited_category_10', 'share_of_visited_category_11', 'share_of_visited_category_12', 'share_of_visited_category_13', 'share_of_visited_category_14', 'share_of_visited_category_15', 'share_of_visited_category_16', 'share_of_visited_category_17', 'share_of_visited_category_18', 'share_of_visited_category_19', 'share_of_visited_category_20', 'share_daytime_вечер', 'share_daytime_день', 'share_daytime_ночь', 'share_daytime_утро', 'mean_session_2025-11-01_00:00:00', 'mean_session_2025-11-02_00:00:00', 'mean_session_2025-11-03_00:00:00', 'mean_session_2025-11-04_00:00:00', 'mean_session_2025-11-05_00:00:00', 'mean_session_2025-11-06_00:00:00', 'mean_session_2025-11-07_00:00:00', 'mean_session_2025-11-08_00:00:00', 'mean_session_2025-11-09_00:00:00', 'mean_session_2025-11-10_00:00:00', 'mean_session_2025-11-11_00:00:00', 'mean_session_2025-11-12_00:00:00', 'mean_session_2025-11-13_00:00:00', 'mean_session_2025-11-14_00:00:00', 'share_of_visited_websites', 'share_of_user_clicks', 'share_of_user_devices', 'users_activity', 'character_age0', 'character_age1', 'character_age2', 'character_age3', 'character_age4', 'character_ctr0', 'character_ctr1', 'character_ctr2', 'character_ctr3', 'character_ctr4']
#
#  Столбцов типа **object: 5**
#  : ['user_id', 'max_active_daytime', 'ads_activity', 'primary_device', 'surf_depth']
#  Столбцов типа **int: 3**
#  : ['count_session_id', 'cloud_usage', 'age_category']
#  Столбцов типа datetime: 0 :[]
#  Столбцов типа bool: 0 :[]
#
# - нормализовали
# -  число уникальных значений в поле:
#     -  user_id: 5205 категории
#     -  ads_activity: 5 категорий ('умеренно' 'очень редко' 'часто' 'редко' 'очень часто') CTR
#     -  primary_device: 4 категории ('ноутбук' 'планшет' 'пк' 'смартфон')
#     -  surf_depth: 3 категории ('средне' 'поверхностно' 'глубоко')
#     -  date: 14 категорий (за первые 2 недели ноября 2025года)
#     -  daytime: 4 категории ('вечер' 'день' 'ночь' 'утро')
#     -  session_id: 939148 категории
#     -  website_category: 20 категорий
# - дубликатов явных и неявных нет

# %% [markdown]
# *Изучим описательные статистики распределения для числового категориального признака 'age_category' и 'cloud_usage'*

# %%
def feature_category (tmp0, value):
    '''
    Исследует категориальные (числовые) признаки по столбцам:
      Считает описательные статистики
      столбчатые диаграммы по столвцам/столбцу
    
    value - столбцы/столбец
    
    '''
    BOLD = '\033[1m' 
    RESET = '\033[0m'
    
    for col in value:
        print(f'Описательные статистики для столбца {BOLD} {col} {RESET}:') 
        print(tmp0[col].describe())
        sns.set_theme(style="darkgrid")
        tmp0[col].value_counts().plot(
            kind='bar',
            edgecolor='black',
            rot=0 
        )

        plt.title(col, fontsize=14)
        plt.xlabel(col, fontsize=12)
        plt.ylabel('Частота', fontsize=12)

        plt.tight_layout()
        plt.show()

# %%
feature_category (df, ['max_active_daytime', 'age_category', 'cloud_usage', 'ads_activity', 'primary_device', 'surf_depth'])
# Out:
# Описательные статистики для столбца  max_active_daytime :
# count     5826
# unique       3
# top       день
# freq      3087
# Name: max_active_daytime, dtype: object
# Описательные статистики для столбца  age_category :
# count    5826.000000
# mean        2.440439
# std         1.381287
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: age_category, dtype: float64
# Описательные статистики для столбца  cloud_usage :
# count    5826.000000
# mean        0.531583
# std         0.499042
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: cloud_usage, dtype: float64
# Описательные статистики для столбца  ads_activity :
# count         5826
# unique           5
# top       умеренно
# freq          2057
# Name: ads_activity, dtype: object
# Описательные статистики для столбца  primary_device :
# count         5826
# unique           4
# ...

# %% [markdown]
# **cloud_usage** - расделение почти 50/50. Тех, кто пользуется облаками 52%

# %% [markdown]
# *Изучим описательные статистики распределения для числовых непрерывных признаков `'share_of_visited_category_01',
#        'share_of_visited_category_02', 'share_of_visited_category_03',
#        'share_of_visited_category_04', 'share_of_visited_category_05',
#        'share_of_visited_category_06', 'share_of_visited_category_07',
#        'share_of_visited_category_08', 'share_of_visited_category_09',
#        'share_of_visited_category_10', 'share_of_visited_category_11',
#        'share_of_visited_category_12', 'share_of_visited_category_13',
#        'share_of_visited_category_14', 'share_of_visited_category_15',
#        'share_of_visited_category_16', 'share_of_visited_category_17',
#        'share_of_visited_category_18', 'share_of_visited_category_19',
#        'share_of_visited_category_20', 'count_session_id',
#        'share_daytime_вечер', 'share_daytime_день', 'share_daytime_ночь',
#        'share_daytime_утро', 'mean_session_2025-11-01_00:00:00',
#        'mean_session_2025-11-02_00:00:00', 'mean_session_2025-11-03_00:00:00',
#        'mean_session_2025-11-04_00:00:00', 'mean_session_2025-11-05_00:00:00',
#        'mean_session_2025-11-06_00:00:00', 'mean_session_2025-11-07_00:00:00',
#        'mean_session_2025-11-08_00:00:00', 'mean_session_2025-11-09_00:00:00',
#        'mean_session_2025-11-10_00:00:00', 'mean_session_2025-11-11_00:00:00',
#        'mean_session_2025-11-12_00:00:00', 'mean_session_2025-11-13_00:00:00',
#        'mean_session_2025-11-14_00:00:00',
#         'share_of_visited_websites', 'share_of_user_clicks',
#        'share_of_user_devices', 'users_activity',
#         'character_age0', 'character_age1', 'character_age2',
#        'character_age3', 'character_age4', 'character_ctr0', 'character_ctr1',
#        'character_ctr2', 'character_ctr3', 'character_ctr4'`*

# %%
def feature_distribution (value):
    '''
    Исследует распределение признаков по столбцам:
      Считает описательные статистики
      Строит гистограммы распределения, ящики с усами по столвцам/столбцу
    
    value - столбцы/столбец
    
    '''
    BOLD = '\033[1m' 
    RESET = '\033[0m'
    
    for col in value:
        print(f'Описательные статистики для столбца {BOLD} {col} {RESET}:')  # Заголовок отдельно
        print(df[col].describe())
        sns.set_theme(style="darkgrid")
        # creating a figure composed of two matplotlib.Axes objects (ax_box and ax_hist)
        f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})

        # assigning a graph to each ax
        sns.boxplot(data=df, x=col, orient="h", ax=ax_box)  # Явно указываем data и x
        sns.histplot(data=df, x=col, ax=ax_hist, bins=50, edgecolor='black')

        # Remove x axis name for the boxplot
        ax_box.set(xlabel='')
        plt.show()

# %%
df.columns
# Out:
# Index(['user_id', 'share_of_visited_category_01',
#        'share_of_visited_category_02', 'share_of_visited_category_03',
#        'share_of_visited_category_04', 'share_of_visited_category_05',
#        'share_of_visited_category_06', 'share_of_visited_category_07',
#        'share_of_visited_category_08', 'share_of_visited_category_09',
#        'share_of_visited_category_10', 'share_of_visited_category_11',
#        'share_of_visited_category_12', 'share_of_visited_category_13',
#        'share_of_visited_category_14', 'share_of_visited_category_15',
#        'share_of_visited_category_16', 'share_of_visited_category_17',
#        'share_of_visited_category_18', 'share_of_visited_category_19',
#        'share_of_visited_category_20', 'count_session_id',
#        'share_daytime_вечер', 'share_daytime_день', 'share_daytime_ночь',
#        'share_daytime_утро', 'mean_session_2025-11-01_00:00:00',
#        'mean_session_2025-11-02_00:00:00', 'mean_session_2025-11-03_00:00:00',
# ...

# %%
feature_distribution (['share_of_visited_category_01',
       'share_of_visited_category_02', 'share_of_visited_category_03',
       'share_of_visited_category_04', 'share_of_visited_category_05',
       'share_of_visited_category_06', 'share_of_visited_category_07',
       'share_of_visited_category_08', 'share_of_visited_category_09',
       'share_of_visited_category_10', 'share_of_visited_category_11',
       'share_of_visited_category_12', 'share_of_visited_category_13',
       'share_of_visited_category_14', 'share_of_visited_category_15',
       'share_of_visited_category_16', 'share_of_visited_category_17',
       'share_of_visited_category_18', 'share_of_visited_category_19',
       'share_of_visited_category_20', 'count_session_id',
       'share_daytime_вечер', 'share_daytime_день', 'share_daytime_ночь',
       'share_daytime_утро', 'mean_session_2025-11-01_00:00:00',
       'mean_session_2025-11-02_00:00:00', 'mean_session_2025-11-03_00:00:00',
       'mean_session_2025-11-04_00:00:00', 'mean_session_2025-11-05_00:00:00',
       'mean_session_2025-11-06_00:00:00', 'mean_session_2025-11-07_00:00:00',
       'mean_session_2025-11-08_00:00:00', 'mean_session_2025-11-09_00:00:00',
       'mean_session_2025-11-10_00:00:00', 'mean_session_2025-11-11_00:00:00',
       'mean_session_2025-11-12_00:00:00', 'mean_session_2025-11-13_00:00:00',
       'mean_session_2025-11-14_00:00:00', 
        'share_of_visited_websites', 'share_of_user_clicks',
       'share_of_user_devices', 'users_activity',
        'character_age0', 'character_age1', 'character_age2',
       'character_age3', 'character_age4', 'character_ctr0', 'character_ctr1',
       'character_ctr2', 'character_ctr3', 'character_ctr4'])
# Out:
# Описательные статистики для столбца  share_of_visited_category_01 :
# count    5826.000000
# mean        0.049933
# std         0.031232
# min         0.000000
# 25%         0.027000
# 50%         0.049000
# 75%         0.070000
# max         0.183000
# Name: share_of_visited_category_01, dtype: float64
# Описательные статистики для столбца  share_of_visited_category_02 :
# count    5826.000000
# mean        0.041640
# std         0.029354
# min         0.000000
# 25%         0.019000
# 50%         0.040000
# 75%         0.061000
# max         0.181000
# Name: share_of_visited_category_02, dtype: float64
# Описательные статистики для столбца  share_of_visited_category_03 :
# count    5826.000000
# mean        0.065476
# std         0.051977
# min         0.000000
# 25%         0.020000
# 50%         0.060000
# 75%         0.102000
# max         0.261000
# Name: share_of_visited_category_03, dtype: float64
# Описательные статистики для столбца  share_of_visited_category_04 :
# ...

# %% [markdown]
# **share_of_visited_websites** доля интернет-активности пользователя приходится в зависимости от посещения  разных категорий сайтов
# На самые популярные категории сайтов заходит от 5% до 9% пользователей.
# Распределение нормальное, правостороннее
# Есть выбросы, т.е. есть несколько особо часто посещаемых категорий сайтов
#
# **share_daytime** распределение активности пользователя во времени в процентах
# Наблюдается цикличность, разные группы пользователей посещают сайты в разное время
# Распределение многовершинное, левостороннее
# На пик активности в среднем приходится 34% пользователей
#
# **mean_session** Среднее количество сессий пользователя в день
# В среднем, пользователь совершает 1,5 2 сессии в день. Редкие фанаты совершают более 7 сессий
# Распределение нормальное правостороннее
#
# **max_active_daytime** Наиболее активное время суток у пользователя
# Распределение правостороннее близко к нормальному, вершина смещена в лево.
# Судя по всему у 50% пользователей действительно есть любимое время посещения.
#
#
# Выбросы есть в полях: share_of_visited_websites, mean_session, max_active_daytime и др., но все они могут объясняться поведением людей, возмзжно это поведение свойственно какой-то определенной возрастной группе, поэтому всю информацию оставим для изучения. С неоднородностью будем босорьтя с помощью StandardScaler

# %% [markdown]
# ### `age_category` - изучение целевой переменной

# %%
display("Уникальные значения:", df['age_category'].unique())
display("Число уникальных значений:", df['age_category'].nunique())
display("Число пропусков:", df['age_category'].isna().sum())
doly_age=round(df['age_category'].mean(), 2)
display(doly_age)
doly_age = round(df['age_category'].value_counts(normalize=True), 2)
display("","Распеделение долей пользователей по возрастным группам:", doly_age)
# Out:
# 'Уникальные значения:'
# array([0, 4, 3, 2, 1], dtype=int8)
# 'Число уникальных значений:'
# 5
# 'Число пропусков:'
# np.int64(0)
# np.float64(2.44)
# ''
# 'Распеделение долей пользователей по возрастным группам:'
# age_category
# 4    0.30
# 2    0.25
# 3    0.22
# 0    0.15
# 1    0.09
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(12, 8))
df.boxplot(column=['age_category'], grid=True, patch_artist=True, vert=False)
plt.title('Распределение возраста')
plt.show()

# %% [markdown]
# **вывод по age_category:**
#
# - 50% пользователей - это люди от 26 и старше 56 лет (категории 2, 3, 4). Медиана 3, чуть выше среднего 2,47, большие значения сосредоточены в левой части распределения.
# - 5 групп возрастов.
# - Более менее равномерное распределение категори. Наблюдается небольшой дисбаланс, особенно для групп 1 (9%) и группы 0 (15%). Для остальных групп (2, 3, 4) разделение более равномерное (от22% до 30%).
# - Выбросов нет

# %% [markdown]
# ### Корреляции
#
# Выявим корреляции между целевой переменной и признаками, а ткаже между признаками

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5826 entries, 0 to 5825
# Data columns (total 60 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   user_id                           5826 non-null   object
#  1   share_of_visited_category_01      5826 non-null   float32
#  2   share_of_visited_category_02      5826 non-null   float32
#  3   share_of_visited_category_03      5826 non-null   float32
#  4   share_of_visited_category_04      5826 non-null   float32
#  5   share_of_visited_category_05      5826 non-null   float32
#  6   share_of_visited_category_06      5826 non-null   float32
#  7   share_of_visited_category_07      5826 non-null   float32
#  8   share_of_visited_category_08      5826 non-null   float32
#  9   share_of_visited_category_09      5826 non-null   float32
#  10  share_of_visited_category_10      5826 non-null   float32
# ...

# %%
def correl_matrix_column(value, col):
    '''
    Строит тепловую карту по корреляционной матрицы для заданной переменной 
    value - столбцы/столбец
    col- столбец, для которого выводят коэффициенты корреляции
    interval_cols - список непрерывных признаков
    При использовании phik крайне важно настроить параметр interval_cols, передав ему список с 
    названиями непрерывных признаков: если этого не сделать, библиотека своими силами будет 
    пытаться разнести признаки по типам, и она часто делает в этом ошибки - от этого в свою очередь 
    мы получаем некорректную оценку корреляций, так как от типа признака зависит метод оценки корреляции.
    '''
    continuous_features = ['share_of_visited_category_01',
       'share_of_visited_category_02', 'share_of_visited_category_03',
       'share_of_visited_category_04', 'share_of_visited_category_05',
       'share_of_visited_category_06', 'share_of_visited_category_07',
       'share_of_visited_category_08', 'share_of_visited_category_09',
       'share_of_visited_category_10', 'share_of_visited_category_11',
       'share_of_visited_category_12', 'share_of_visited_category_13',
       'share_of_visited_category_14', 'share_of_visited_category_15',
       'share_of_visited_category_16', 'share_of_visited_category_17',
       'share_of_visited_category_18', 'share_of_visited_category_19',
       'share_of_visited_category_20', 'share_daytime_вечер',
       'share_daytime_день', 'share_daytime_ночь', 'share_daytime_утро',
       'mean_session_2025-11-01_00:00:00', 'mean_session_2025-11-02_00:00:00',
       'mean_session_2025-11-03_00:00:00', 'mean_session_2025-11-04_00:00:00',
       'mean_session_2025-11-05_00:00:00', 'mean_session_2025-11-06_00:00:00',
       'mean_session_2025-11-07_00:00:00', 'mean_session_2025-11-08_00:00:00',
       'mean_session_2025-11-09_00:00:00', 'mean_session_2025-11-10_00:00:00',
       'mean_session_2025-11-11_00:00:00', 'mean_session_2025-11-12_00:00:00',
       'mean_session_2025-11-13_00:00:00', 'mean_session_2025-11-14_00:00:00',
       'share_of_visited_websites',
       'users_activity', 'character_age0', 'character_age1', 'character_age2',
       'character_age3', 'character_age4', 'character_ctr0', 'character_ctr1',
       'character_ctr2', 'character_ctr3', 'character_ctr4']
    
    correlation_matrix = df[value].phik_matrix(interval_cols=continuous_features)
    
    
    plt.figure(figsize=(2, 10))
    correlation_matrix.loc[correlation_matrix.index != col][[col]].sort_values(by=col, ascending=False)
     
    data_heatmap = correlation_matrix.loc[correlation_matrix.index != col][[col]].sort_values(by=col, ascending=False)
    sns.heatmap(data_heatmap,
            annot=True, 
            fmt='.2f', 
            cmap='coolwarm', 
            linewidths=0.5, 
            cbar=False 
           )
    plt.title(f'Тепловая карта коэффициента phi_k \n для данных {col}')
    plt.show()
    


correl_matrix_column(['share_of_visited_category_01',
       'share_of_visited_category_02', 'share_of_visited_category_03',
       'share_of_visited_category_04', 'share_of_visited_category_05',
       'share_of_visited_category_06', 'share_of_visited_category_07',
       'share_of_visited_category_08', 'share_of_visited_category_09',
       'share_of_visited_category_10', 'share_of_visited_category_11',
       'share_of_visited_category_12', 'share_of_visited_category_13',
       'share_of_visited_category_14', 'share_of_visited_category_15',
       'share_of_visited_category_16', 'share_of_visited_category_17',
       'share_of_visited_category_18', 'share_of_visited_category_19',
       'share_of_visited_category_20', 'share_daytime_вечер',
       'share_daytime_день', 'share_daytime_ночь', 'share_daytime_утро',
       'mean_session_2025-11-01_00:00:00', 'mean_session_2025-11-02_00:00:00',
       'mean_session_2025-11-03_00:00:00', 'mean_session_2025-11-04_00:00:00',
       'mean_session_2025-11-05_00:00:00', 'mean_session_2025-11-06_00:00:00',
       'mean_session_2025-11-07_00:00:00', 'mean_session_2025-11-08_00:00:00',
       'mean_session_2025-11-09_00:00:00', 'mean_session_2025-11-10_00:00:00',
       'mean_session_2025-11-11_00:00:00', 'mean_session_2025-11-12_00:00:00',
       'mean_session_2025-11-13_00:00:00', 'mean_session_2025-11-14_00:00:00',
       'max_active_daytime', 'cloud_usage', 'age_category', 'ads_activity',
       'primary_device', 'surf_depth', 'share_of_visited_websites',
       'users_activity', 'character_age0', 'character_age1', 'character_age2',
       'character_age3', 'character_age4', 'character_ctr0', 'character_ctr1',
       'character_ctr2', 'character_ctr3', 'character_ctr4'], 'age_category')

# %% [markdown]
# С целевой переменной `age_category` наиболее сильные взаимосвязи с 'character_age2' (0.75), 'share_daytime' (0.73 - 0.53). Также обнаружены связи послабее с полями: cloud_usage (0.22), surf_depth (0.14) и mean_session и др.

# %%
df.columns
# Out:
# Index(['user_id', 'share_of_visited_category_01',
#        'share_of_visited_category_02', 'share_of_visited_category_03',
#        'share_of_visited_category_04', 'share_of_visited_category_05',
#        'share_of_visited_category_06', 'share_of_visited_category_07',
#        'share_of_visited_category_08', 'share_of_visited_category_09',
#        'share_of_visited_category_10', 'share_of_visited_category_11',
#        'share_of_visited_category_12', 'share_of_visited_category_13',
#        'share_of_visited_category_14', 'share_of_visited_category_15',
#        'share_of_visited_category_16', 'share_of_visited_category_17',
#        'share_of_visited_category_18', 'share_of_visited_category_19',
#        'share_of_visited_category_20', 'count_session_id',
#        'share_daytime_вечер', 'share_daytime_день', 'share_daytime_ночь',
#        'share_daytime_утро', 'mean_session_2025-11-01_00:00:00',
#        'mean_session_2025-11-02_00:00:00', 'mean_session_2025-11-03_00:00:00',
# ...

# %% [markdown]
# Построим **тепловую карту взаимосвязей между всеми признаками**

# %%
columns_for_analiz=['share_of_visited_category_01',
       'share_of_visited_category_02', 'share_of_visited_category_03',
       'share_of_visited_category_04', 'share_of_visited_category_05',
       'share_of_visited_category_06', 'share_of_visited_category_07',
       'share_of_visited_category_08', 'share_of_visited_category_09',
       'share_of_visited_category_10', 'share_of_visited_category_11',
       'share_of_visited_category_12', 'share_of_visited_category_13',
       'share_of_visited_category_14', 'share_of_visited_category_15',
       'share_of_visited_category_16', 'share_of_visited_category_17',
       'share_of_visited_category_18', 'share_of_visited_category_19',
       'share_of_visited_category_20', 'share_daytime_вечер',
       'share_daytime_день', 'share_daytime_ночь', 'share_daytime_утро',
       'mean_session_2025-11-01_00:00:00', 'mean_session_2025-11-02_00:00:00',
       'mean_session_2025-11-03_00:00:00', 'mean_session_2025-11-04_00:00:00',
       'mean_session_2025-11-05_00:00:00', 'mean_session_2025-11-06_00:00:00',
       'mean_session_2025-11-07_00:00:00', 'mean_session_2025-11-08_00:00:00',
       'mean_session_2025-11-09_00:00:00', 'mean_session_2025-11-10_00:00:00',
       'mean_session_2025-11-11_00:00:00', 'mean_session_2025-11-12_00:00:00',
       'mean_session_2025-11-13_00:00:00', 'mean_session_2025-11-14_00:00:00',
       'max_active_daytime', 'cloud_usage', 'age_category', 'ads_activity',
       'primary_device', 'surf_depth', 'share_of_visited_websites',
       'users_activity', 'character_age0', 'character_age1', 'character_age2',
       'character_age3', 'character_age4', 'character_ctr0', 'character_ctr1',
       'character_ctr2', 'character_ctr3', 'character_ctr4']

continuous_features =['share_of_visited_category_01',
       'share_of_visited_category_02', 'share_of_visited_category_03',
       'share_of_visited_category_04', 'share_of_visited_category_05',
       'share_of_visited_category_06', 'share_of_visited_category_07',
       'share_of_visited_category_08', 'share_of_visited_category_09',
       'share_of_visited_category_10', 'share_of_visited_category_11',
       'share_of_visited_category_12', 'share_of_visited_category_13',
       'share_of_visited_category_14', 'share_of_visited_category_15',
       'share_of_visited_category_16', 'share_of_visited_category_17',
       'share_of_visited_category_18', 'share_of_visited_category_19',
       'share_of_visited_category_20', 'share_daytime_вечер',
       'share_daytime_день', 'share_daytime_ночь', 'share_daytime_утро',
       'mean_session_2025-11-01_00:00:00', 'mean_session_2025-11-02_00:00:00',
       'mean_session_2025-11-03_00:00:00', 'mean_session_2025-11-04_00:00:00',
       'mean_session_2025-11-05_00:00:00', 'mean_session_2025-11-06_00:00:00',
       'mean_session_2025-11-07_00:00:00', 'mean_session_2025-11-08_00:00:00',
       'mean_session_2025-11-09_00:00:00', 'mean_session_2025-11-10_00:00:00',
       'mean_session_2025-11-11_00:00:00', 'mean_session_2025-11-12_00:00:00',
       'mean_session_2025-11-13_00:00:00', 'mean_session_2025-11-14_00:00:00',
       'share_of_visited_websites',
       'users_activity', 'character_age0', 'character_age1', 'character_age2',
       'character_age3', 'character_age4', 'character_ctr0', 'character_ctr1',
       'character_ctr2', 'character_ctr3', 'character_ctr4']
correlation_matrix=df[columns_for_analiz].phik_matrix(interval_cols=continuous_features)
plt.figure(figsize=(18, 16))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, linewidths=0.5)
plt.title('Корреляционная матрица')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Обнаружили **мультиколинеарность**, с коэффициентом **0.9**, между признаками:
# - 'character_ctr0' с 'character_age4'
# - 'character_ctr1' с 'character_age4'
#
# Чтобы избавиться от колинеарности, удалим из датафрейма: `'character_ctr0', 'character_ctr1'`.
#
# Также, удалим нулевые корреляции:
# `'mean_session_2025-11-01_00:00:00', 'mean_session_2025-11-05_00:00:00', 'mean_session_2025-11-08_00:00:00', 'mean_session_2025-11-10_00:00:00'`

# %%
df=df.drop(columns=['character_ctr0', 'character_ctr1', 'mean_session_2025-11-01_00:00:00', 'mean_session_2025-11-05_00:00:00', 
                    'mean_session_2025-11-08_00:00:00', 'mean_session_2025-11-10_00:00:00'])

# %%
columns_for_analiz=['share_of_visited_category_01',
       'share_of_visited_category_02', 'share_of_visited_category_03',
       'share_of_visited_category_04', 'share_of_visited_category_05',
       'share_of_visited_category_06', 'share_of_visited_category_07',
       'share_of_visited_category_08', 'share_of_visited_category_09',
       'share_of_visited_category_10', 'share_of_visited_category_11',
       'share_of_visited_category_12', 'share_of_visited_category_13',
       'share_of_visited_category_14', 'share_of_visited_category_15',
       'share_of_visited_category_16', 'share_of_visited_category_17',
       'share_of_visited_category_18', 'share_of_visited_category_19',
       'share_of_visited_category_20', 'share_daytime_вечер',
       'share_daytime_день', 'share_daytime_ночь', 'share_daytime_утро',
       'mean_session_2025-11-02_00:00:00',
       'mean_session_2025-11-03_00:00:00', 'mean_session_2025-11-04_00:00:00',
        'mean_session_2025-11-06_00:00:00',
       'mean_session_2025-11-07_00:00:00', 
       'mean_session_2025-11-09_00:00:00', 
       'mean_session_2025-11-11_00:00:00', 'mean_session_2025-11-12_00:00:00',
       'mean_session_2025-11-13_00:00:00', 'mean_session_2025-11-14_00:00:00',
       'max_active_daytime', 'cloud_usage', 'age_category', 'ads_activity',
       'primary_device', 'surf_depth', 'share_of_visited_websites',
       'users_activity', 'character_age0', 'character_age1', 'character_age2',
       'character_age3', 'character_age4', 
       'character_ctr2', 'character_ctr3', 'character_ctr4']

continuous_features =['share_of_visited_category_01',
       'share_of_visited_category_02', 'share_of_visited_category_03',
       'share_of_visited_category_04', 'share_of_visited_category_05',
       'share_of_visited_category_06', 'share_of_visited_category_07',
       'share_of_visited_category_08', 'share_of_visited_category_09',
       'share_of_visited_category_10', 'share_of_visited_category_11',
       'share_of_visited_category_12', 'share_of_visited_category_13',
       'share_of_visited_category_14', 'share_of_visited_category_15',
       'share_of_visited_category_16', 'share_of_visited_category_17',
       'share_of_visited_category_18', 'share_of_visited_category_19',
       'share_of_visited_category_20', 'share_daytime_вечер',
       'share_daytime_день', 'share_daytime_ночь', 'share_daytime_утро',
       'mean_session_2025-11-02_00:00:00',
       'mean_session_2025-11-03_00:00:00', 'mean_session_2025-11-04_00:00:00',
       'mean_session_2025-11-06_00:00:00',
       'mean_session_2025-11-07_00:00:00', 
       'mean_session_2025-11-09_00:00:00', 
       'mean_session_2025-11-11_00:00:00', 'mean_session_2025-11-12_00:00:00',
       'mean_session_2025-11-13_00:00:00', 'mean_session_2025-11-14_00:00:00',
       'share_of_visited_websites',
       'users_activity', 'character_age0', 'character_age1', 'character_age2',
       'character_age3', 'character_age4', 
       'character_ctr2', 'character_ctr3', 'character_ctr4']

correlation_matrix=df[columns_for_analiz].phik_matrix(interval_cols=continuous_features)
plt.figure(figsize=(18, 16))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, linewidths=0.5)
plt.title('Корреляционная матрица')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.shape
# Out:
# (5826, 54)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Построена тепловая карта phik, корректно заданы continuous-признаки, обнаружена мультиколлинеарность, признаки удалены с пояснением причины.
# </div>

# %% [markdown]
# ##### Выводы по EDA
#
# - Датафрейм **df** содержит **939148** строк и **54** столбца
# - Рассчитаны признаки:
#   ###### Таким образом, рассчитано и добавлено в датафрейм **df** 15 показателей:
# - **share_of_user_clicks** - индекс кликабельности пользователя в зависимости от категории ads_activity, на 1000 кликов
# - **share_of_user_devices** - доля видов устройств на пользователя по primary_device, на 1000 устройств
# - **users_activity** -  обобщенный показатель активности пользователя: перемножим `'age_category'` (возрастная категория), `'share_of_user_clicks'` (доля интенсивности кликов пользователя в зависимости от категории ads_activity), `'share_of_user_devices'` , `'share_of_visited_websites'`.
# - **character_age0**, **character_age1**,	**character_age2**,	**character_age3**,	**character_age4** - обобщающие показатели, характеризующие деятельность пользователя (основные характеристики и использование облаков) в зависимости от возраста
#
# - **character_ctr0**, **character_ctr1**,	**character_ctr2**,	**character_ctr3**,	**character_ctr4** - обобщающие показатели, характеризующие деятельность пользователя (основные характеристики и использование облаков) в зависимости от CTR
# - доля интернет-активности пользователя приходится в зависимости от посещение  разных категорий сайтов website_category (`share_of_visited_websites`)
# - распределение активности пользователя во времени в процентах (`share_of_daytime`)
# - Среднее количество сессий пользователя в день (`mean_session`)
# - Наиболее активное время суток у пользователя (`max_active_daytime`)
#
# Таким образом, всего рассчитано и добавлено 15 показателей.
#
# - Проведены преобразования:
#   - названия столбцов датафрейма приведены к стилю **snake case**
#   - нормализовали текстовые поля
#   - определено число уникальных значений (категорий) в текстовых полях:
#      `ads_activity`: **5** категорий ('умеренно' 'очень редко' 'часто' 'редко' 'очень часто') CTR
#      `primary_device`: **4** категории ('ноутбук' 'планшет' 'пк' 'смартфон')
#      `surf_depth`: **3** категории ('средне' 'поверхностно' 'глубоко')
#      `date`: **14** категорий (за первые 2 недели ноября 2025года)
#      `website_category`: **20** категорий
#   - дубликатов явных и неявных нет
#   - пропусков нет
# - Изучили описательные статистики распределения для числовых непрерывных признаков `'share_of_visited_websites', 'share_of_daytime', 'mean_session', 'max_active_daytime'` и др.
# **share_of_visited_websites** доля интернет-активности пользователя приходится в зависимости от посещения разных категорий сайтов На самые популярные категории сайтов заходит от 5% до 9% пользователей. Распределение нормальное, правостороннее Есть выбросы, т.е. есть несколько особо часто посещаемых категорий сайтов
#
# **share_of_daytime** распределение активности пользователя во времени в процентах Наблюдается цикличность, разные группы пользователей посещают сайты в разное время Распределение многовершинное, левостороннее На пик активности в среднем приходится 34% пользователей
#
# **mean_session** Среднее количество сессий пользователя в день В среднем, пользователь совершает 1,5 2 сессии в день. Редкие фанаты совершают более 7 сессий Распределение нормальное правостороннее
#
# **max_active_daytime** Наиболее активное время суток у пользователя Распределение правостороннее близко к нормальному, вершина смещена в лево. Судя по всему у 50% пользователей действительно есть любимое время посещения.
#
# Выбросы есть в полях: share_of_visited_websites, mean_session, max_active_daytime и др., но все они могут объясняться поведением людей, возможно это поведение свойственно какой-то определенной возрастной группе, поэтому всю информацию оставим для изучения. С неоднородностью будем бороться с помощью **StandardScaler**
#
# - Изучили описательные статистики распределения для числового категориального признака 'age_category' и 'cloud_usage'
#    - **cloud_usage** - расделение почти 50/50. Тех, кто пользуется облаками 52%
# - Целевая переменная `age_category`:
#   - 50% пользователей - это люди от 26 и старше 56 лет (категории 2, 3, 4). Медиана 3, чуть выше среднего 2,47, большие значения сосредоточены в левой части распределения.
#   - 5 групп возрастов.
#   - Более менее равномерное распределение категори. Наблюдается небольшой дисбаланс, особенно для групп 1 (9%) и группы 0 (15%). Для остальных групп (2, 3, 4) разделение более равномерное (от22% до 30%).
#   - Выбросов нет
#
# - Обнаружили **мультиколинеарность**, с коэффициентом **0.9**, между признаками:
# - 'character_ctr0' с 'character_age4'
# - 'character_ctr1' с 'character_age4'
#
# Чтобы избавиться от колинеарности, удалим из датафрейма: `'character_ctr0', 'character_ctr1'`.
#
# Также, удалим нулевые корреляции:
# `'mean_session_2025-11-01_00:00:00', 'mean_session_2025-11-05_00:00:00', 'mean_session_2025-11-08_00:00:00', 'mean_session_2025-11-10_00:00:00'`
#
# ___________
#
# Таким образом, во время предобработи данных проведём:
# 1. Трансформируем текстовые признаки в числовые, применив:
#    - OneHotEncoder для небольших категорий у пртзнаков: `ads_activity`, `primary_device`, `surf_depth`, `date`, `website_category`
# 2. Поскольку есть выбросы, по стандартизируем числовые столбцы с помощью **StandardScaler**
# 3. Применим фильтр к числовым столбцам VarianceTreshold и удалим признаки с нулевой вариацией
# 4. Применим обертку RFE и выберем самые информативные признаки

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5826 entries, 0 to 5825
# Data columns (total 54 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   user_id                           5826 non-null   object
#  1   share_of_visited_category_01      5826 non-null   float32
#  2   share_of_visited_category_02      5826 non-null   float32
#  3   share_of_visited_category_03      5826 non-null   float32
#  4   share_of_visited_category_04      5826 non-null   float32
#  5   share_of_visited_category_05      5826 non-null   float32
#  6   share_of_visited_category_06      5826 non-null   float32
#  7   share_of_visited_category_07      5826 non-null   float32
#  8   share_of_visited_category_08      5826 non-null   float32
#  9   share_of_visited_category_09      5826 non-null   float32
#  10  share_of_visited_category_10      5826 non-null   float32
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Проведен детальный EDA анализ - хорошая работа
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Совет:</b>
#
#  Советую обратить внимание на библиотеки sweetviz и ydata_profiling помогут в проведении более тщательного EDA анализа. Я использую их в своей работе для первичного осмотра данных, но это можно делать и с помощью ручного вызова функций дефолтных библиотек. Данные библиотеки хороши для максимизации комфорта презентации результатов анализа бизнес-пользователям.
#
# Очень просты в использоовании, на вход кладется датафрейм: ydata_profiling.ProfileReport(df)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b> Спасибо
# </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Разделим данные на: обучающую и валидационную выборки
#
# **Важно:** при разделении на обучающую и тестовую выборки важно не допустить, чтобы одни и те же пользователи попали в обе выборки. Различить пользователей поможет их уникальный идентификатор. В тестовую выборку нужно отправить от 20 до 30 процентов уникальных пользователей.
#
#
# Чтобы разделить данные на выборки нам требуется учесть:
# 1. одни и те же пользователи (и часть записей о них) не попали в разные выборки (train, val, test)
# 2. соблюсти распределение классов по целевой переменной age_category
# Здесь использование обычного метода **train_test_splnt()** не подходит. Поэтому, для решения задачи воспользуемся **GroupShuffleSplit**. Он разделяет данные на основе групп (`user_id`).
#
# Чтобы соблюсти дисбаланс классов в выборках по целевой переменной `age_category`, проведём предварительную стратификацию групп, т.к. реализованного **stratify** нет у **GroupShuffleSplit**.
#
# Для этого воспользуемся функцией **stratify_groups_by_label** в которой **StratifiedShuffleSplit** разобьёт на выборки с учетом пропорций классов, а потом отфильтруем датафрейм по `user_id`.

# %% [markdown]
# Сперва выделим **20% val ** выборки

# %%
def stratify_groups_by_label(df, group_col, label_col, test_size=0.2):
    """Разделяет GROUPS (не строки!), сохраняя пропорции LABEL"""
    gss_inner = StratifiedShuffleSplit(n_splits=1, test_size=test_size)
    
    unique_groups = df[group_col].unique()
    labels_of_groups = df.groupby(group_col)[label_col].first() 
    
    for train_gid, test_gid in gss_inner.split(unique_groups, labels_of_groups):
        return unique_groups[train_gid], unique_groups[test_gid]

# %% [markdown]
# Применив функцию, получаем списки по `user_id`.
#
# С помощью `.isin` отбираем записи

# %%
train_users, val_users = stratify_groups_by_label(df, 'user_id', 'age_category', test_size=0.2)


train = df[df['user_id'].isin(train_users)]
val = df[df['user_id'].isin(val_users)]

# %% [markdown]
# Внимательно изучим датафрейм **test**. В нём представлены все столбцы **df**. Выделим из него **X** и **y**, а так же для выборок **val**, **train**.
#
# Для этого создадим словарь, в цикле создадим датафреймы.
#
# Чтобы `y` выводился коректно применим к строке `final_data[f'y_{name}']...` метод `squeeze()` - приводит данные к виду "одномерный массив" , вместо двумерного столбца (таблицу N x 1)
#
# пример: y_train = y_train.squeeze()

# %%
data_splits = {'train': train, 'val': val}

final_data = {} 

for name, temp_df in data_splits.items():
    current_df = temp_df.copy() 
    
    X_temp = current_df.drop(columns=['age_category', 'user_id'])
    y_temp = current_df['age_category'].astype('category') 
    
    final_data[f'X_{name}'] = X_temp.reset_index(drop=True)
    final_data[f'y_{name}'] = y_temp.reset_index(drop=True).to_frame(name='target').squeeze()

    #y_train = y_train.squeeze() - приводим данные к виду "одномерный массив" , вместо двумерного столбца (таблицу N x 1)

# %% [markdown]
# Извлечём из словаря переменные X_train, y_train, ...

# %%
X_train, y_train = final_data['X_train'], final_data['y_train']
X_val, y_val     = final_data['X_val'], final_data['y_val']

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4660 entries, 0 to 4659
# Data columns (total 52 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   share_of_visited_category_01      4660 non-null   float32
#  1   share_of_visited_category_02      4660 non-null   float32
#  2   share_of_visited_category_03      4660 non-null   float32
#  3   share_of_visited_category_04      4660 non-null   float32
#  4   share_of_visited_category_05      4660 non-null   float32
#  5   share_of_visited_category_06      4660 non-null   float32
#  6   share_of_visited_category_07      4660 non-null   float32
#  7   share_of_visited_category_08      4660 non-null   float32
#  8   share_of_visited_category_09      4660 non-null   float32
#  9   share_of_visited_category_10      4660 non-null   float32
#  10  share_of_visited_category_11      4660 non-null   float32
# ...

# %% [markdown]
# Проверим размерности выборок **train, val**

# %%
print(f"Общее количество образцов: {len(df)}")
print("-" * 40)
print("Набор данных | Размер | Цель")
print("-" * 40)
print(f"Тренировочный (Train) | {len(X_train)} | Обучение базовой модели")
print(f"Валидационный (Val)   | {len(X_val)}   | Настройка гиперпараметров")
print("-" * 40)
print(f"Сумма: {len(X_train) + len(X_val)}")
# Out:
# Общее количество образцов: 5826
# ----------------------------------------
# Набор данных | Размер | Цель
# ----------------------------------------
# Тренировочный (Train) | 4660 | Обучение базовой модели
# Валидационный (Val)   | 1166   | Настройка гиперпараметров
# ----------------------------------------
# Сумма: 5826

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Разделение на выборки учитывает, что один пользователь не должен попасть в разные выборки (стратифицированное разбиение по группам user_id) — правильный и не самый очевидный подход для этой задачи.
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Совет:</b> Ценность этого разбиения снижается тем, что внутри каждой выборки всё ещё остаются сотни почти одинаковых строк на одного пользователя (см. комментарий выше про объединение таблиц). После исправления агрегации к уровню пользователя этот код разбиения не изменится и продолжит работать корректно.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b> '👍' Спасибо
# </div>

# %% [markdown]
# ## Предобработка данных — построение пайплайнов
#
# ####  Создадим пайплайн для предобработки данных
# **Для числовых признаков:**
# - Корректно заполним пропуски — средним, медианой или другим методом.
# - Масштабируйте данные с помощью `StandardScaler`
# - уберем признаки с нулевой вариацией с помощью фильтра **VarainceTreshold**
#
# **Для категориальных признаков:**
# - Корректно заполним пропуски —  модой.
# - Применим кодирование: **One-Hot Encoding** для признаков с малой кардинальностью.

# %%
num_column = X_train.select_dtypes(include=['number']).columns.tolist()
cat_column = X_train.select_dtypes(include=['object']).columns.tolist()

X_train=X_train.reset_index(drop=True)
y_train=y_train.reset_index(drop=True)

num_pipeline = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('vt', VarianceThreshold(threshold=0.001)),
    ('scaler', StandardScaler())
])

cat_pipeline = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder(sparse_output=False, handle_unknown='ignore'))
])


preprocessor = ColumnTransformer(transformers=[
    ('num_pipeline', num_pipeline, num_column),
    ('cat_pipeline', cat_pipeline, cat_column)
    
    ],
    remainder='drop',
    verbose_feature_names_out=False                             
)

# %% [markdown]
# Обработка признаков завершена
#
# Теперь приступим к созданию и обучению моделей.

# %% [markdown]
# ## Обучение и оценка базовой модели
#
# - оценка базовой моделу dummy
# - оценка базовой **lr**
# - оценка базовой **svc**

# %% [markdown]
# Создаю **dummy** модель

# %%
dummy_clf = DummyClassifier(strategy='stratified', random_state=RANDOM_SEED)

# %% [markdown]
# Выполняю кросс-валидацию для Dummy, чтобы найти F1_macro

# %%
cv_scores = cross_val_score(
    dummy_clf,
    X_train,
    y_train,
    cv=5,
    scoring='f1_weighted',
    n_jobs=-1
)

# %%
display(f'Средний F1_weighted по Dummy модели: {cv_scores.mean():.4f}')
# Out:
# 'Средний F1_weighted по Dummy модели: 0.2212'

# %% [markdown]
# Средний F1_macro по Dummy модели: 0.2268

# %% [markdown]
# **Создаём финальный пайплайн для lr**.
#
# Отберём самые значимые признаки, применив обёртку **RFE**
#
# lr_pipeline = Pipeline(steps=[
#     ('preprocessor', preprocessor),
#     ('features_selector', RFE(
#         estimator = LogisticRegression(solver='lbfgs', class_weight='balanced'),
#         n_features_to_select=49,
#         step=1
#     )),
#     ('classifier', LogisticRegression(solver='lbfgs', class_weight='balanced'))
# ])
#
# Если использовать обертку
#
#
# Для многоклассовой логистической регрессии задаю solver='lbfgs'

# %%
lr_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('features_selector', RFE(
        estimator = LogisticRegression(solver='lbfgs', class_weight='balanced', max_iter=1000),
        n_features_to_select=20,
        step=1
    )),
    ('classifier', LogisticRegression(solver='lbfgs', class_weight='balanced', max_iter=1000))
])

# %% [markdown]
# обучаю пайплайн **lr**

# %%
lr_pip = lr_pipeline.fit(X_train, y_train)
display('Обучение закончено')
# Out:
# 'Обучение закончено'

# %% [markdown]
# После обучения **lr** посмотрим список отобранных столбцов

# %%
rfe_step = lr_pipeline.named_steps['preprocessor']
feature_names=rfe_step.get_feature_names_out()
display(feature_names)
# Out:
# array(['share_of_visited_category_03', 'share_of_visited_category_08',
#        'share_of_visited_category_13', 'share_of_visited_category_18',
#        'count_session_id', 'share_daytime_вечер', 'share_daytime_день',
#        'share_daytime_утро', 'cloud_usage', 'share_of_visited_websites',
#        'share_of_user_clicks', 'share_of_user_devices', 'users_activity',
#        'character_age0', 'character_age1', 'character_age2',
#        'character_age3', 'character_age4', 'character_ctr2',
#        'character_ctr3', 'character_ctr4', 'max_active_daytime_вечер',
#        'max_active_daytime_день', 'max_active_daytime_утро',
#        'ads_activity_очень редко', 'ads_activity_очень часто',
#        'ads_activity_редко', 'ads_activity_умеренно',
#        'ads_activity_часто', 'primary_device_ноутбук',
#        'primary_device_пк', 'primary_device_планшет',
#        'primary_device_смартфон', 'surf_depth_глубоко',
#        'surf_depth_поверхностно', 'surf_depth_средне'], dtype=object)

# %% [markdown]
# Считаю метрики для логистической регресси на **train**

# %%
lr_metrics = { 
    'f1_macro': 'f1_macro', 
    'precision_macro': 'precision_macro', 
    'recall_macro': 'recall_macro' }


scores_lr_basa = cross_validate(
    estimator=lr_pipeline,
    X=X_train,
    y=y_train,
    cv=cv, 
    scoring=lr_metrics,
    return_train_score=True, 
    n_jobs=-1 
)

# %% [markdown]
# Вывожу метрики базовой **lr**

# %%
mean_f1_lr = np.mean(scores_lr_basa['test_f1_macro']) 
std_f1 = np.std(scores_lr_basa['test_f1_macro']) 

mean_precision = np.mean(scores_lr_basa['test_precision_macro']) 
mean_recall = np.mean(scores_lr_basa['test_recall_macro']) 

display(f'F1 macro: {mean_f1_lr:.4f} (+/- {std_f1:.4f})') 
display(f'Precision macro: {mean_precision:.4f}') 
display(f'Recall macro: {mean_recall:.4f}')
# Out:
# 'F1 macro: 0.9686 (+/- 0.0060)'
# 'Precision macro: 0.9688'
# 'Recall macro: 0.9689'

# %% [markdown]
# 'F1 macro: 0.9558 (+/- 0.0076)'
# 'Precision macro: 0.9543'
# 'Recall macro: 0.9584'
#
# Метрики на базовой модели **логистической регресси** лучше **dummy**, но хорошие для продакшена

# %% [markdown]
# **Создаём финальный пайплайн для SVC**.
#
# Отберём самые значимые признаки, применив обёртку **RFE**
#
# Создаю отдельные два экземпляра для финального пайплайна **SVC*. устанавливаю  **probability=False**, чтобы сделать отбор признаков быстрее. Вепроятности классов в этой задаче не нужны
#
# Для более быстрой работы вместо **SVC** использую **LinearSVC**, он более быстрый, используется при линейных вычислениях, когда вероятности не нужны (их рассчитывают при калибровке, если надо). Нелинейные ядра попробую при **GrenSearch**

# %%
svc_for_RFE = LinearSVC(
    C=1.0,              
    class_weight='balanced',
    dual=False,
    random_state=RANDOM_SEED
)
final_svc_classifier = LinearSVC(
    C=1.0,              
    class_weight='balanced',
    dual=False,
    random_state=RANDOM_SEED
)

# %%
svc_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('features_selector', RFE(
        estimator = svc_for_RFE,
        n_features_to_select=20,
        step=1
    )),
    ('classifier', final_svc_classifier)
])

# %% [markdown]
# Обучаю модель **SVC**

# %%
svc_pip = svc_pipeline.fit(X_train, y_train)
display('Обучение завершено')
# Out:
# 'Обучение завершено'

# %% [markdown]
# После обучения **svc** посмотрим список отобранных столбцов

# %%
svc_rfe_steps = svc_pipeline.named_steps['features_selector']

# %%
feature_names_svc = svc_rfe_steps.get_feature_names_out()
display(feature_names_svc)
# Out:
# array(['cloud_usage', 'users_activity', 'character_age0',
#        'character_age1', 'character_age2', 'character_age3',
#        'character_age4', 'character_ctr2', 'character_ctr3',
#        'character_ctr4', 'max_active_daytime_вечер',
#        'max_active_daytime_день', 'max_active_daytime_утро',
#        'ads_activity_очень часто', 'primary_device_ноутбук',
#        'primary_device_пк', 'primary_device_смартфон',
#        'surf_depth_глубоко', 'surf_depth_поверхностно',
#        'surf_depth_средне'], dtype=object)

# %% [markdown]
# Считаю метрики для SVC на **train**

# %%
svc_metrics = { 
    'f1_macro': 'f1_macro', 
    'precision_macro': 'precision_macro', 
    'recall_macro': 'recall_macro' }


scores_svc_basa = cross_validate(
    estimator=svc_pipeline,
    X=X_train,
    y=y_train,
    cv=cv, 
    scoring=svc_metrics,
    return_train_score=True, 
    n_jobs=-1 
)

# %% [markdown]
# Вывожу метрики для **SVC**

# %%
mean_f1_svc = np.mean(scores_svc_basa['test_f1_macro']) 
std_f1 = np.std(scores_svc_basa['test_f1_macro']) 

mean_precision = np.mean(scores_svc_basa['test_precision_macro']) 
mean_recall = np.mean(scores_svc_basa['test_recall_macro']) 

display(f'F1 macro: {mean_f1_svc:.4f} (+/- {std_f1:.4f})') 
display(f'Precision macro: {mean_precision:.4f}') 
display(f'Recall macro: {mean_recall:.4f}')
# Out:
# 'F1 macro: 0.9782 (+/- 0.0035)'
# 'Precision macro: 0.9795'
# 'Recall macro: 0.9777'

# %% [markdown]
# 'F1 macro: 0.9794 (+/- 0.0039)'
# 'Precision macro: 0.9813'
# 'Recall macro: 0.9780'
#
# Метрики для SVC модели чуть лучше логистической регрессии. Можно рекомендовать для продакшена.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Хорошее покрытие архитектур — логистическая регрессия и SVC с линейным, полиномиальным и rbf-ядром — ровно то, что требовалось заданием.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Ошибка:</b> Во всех моделях (Dummy, LogisticRegression, SVC) метрика — <code>f1_weighted</code>, а не <code>f1_macro</code>, как явно требует задание ("макро-усреднение", "F1-macro ≥ 0.75"). Weighted-усреднение при дисбалансе классов даёт менее показательную и завышенную оценку. Нужно пересчитать через f1_macro.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b> Сделано
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Изменения:</b> Были изменены метрики с weighted на macro здесь и дальше по файлу
# </div>

# %% [markdown]
# ## Создание и отбор признаков

# %% [markdown]
# Мне не понятен этот пункт в данном месте исследования.
#
# Ранее были созданы признаки в таблице `new_df_ds_s13_visits`:
# - доля интернет-активности пользователя приходится в зависимости от посещение  разных категорий сайтов     (share_of_visited_websites)
# - распределение активности пользователя во времени в процентах (share_of_daytime)
# - наиболее активное время суток у пользователя (max_active_daytime)
# Они попали в итоговый датафрейм **df** и в обучающую, валидационную и тестовую выборки:
#
#  -   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
# - 0   cloud_usage                560507 non-null  int8
# - 1   ads_activity               560507 non-null  object
# - 2   primary_device             560507 non-null  object
# - 3   surf_depth                 560507 non-null  object
# - 4   date                       560507 non-null  object
# - 5   website_category           560507 non-null  object
# - 6   share_of_visited_websites  560507 non-null  float32
# - 7   share_of_daytime           560507 non-null  float32
# - 8   max_active_daytime         560507 non-null  int16
#
#
#
# Пожалуй, в этом месте исследования можно сказать только, что метрика **f1-macro** на всех ядрах и моделях получилась около **0.38**, что не достаточно для продакшена. Поэтому попробуем увеличить эту метрику за счет введения новых вычисляемых признаков. НО, добавим их на этапе 2.9 и посмотрим, есть ли толк! - Толк есть!

# %% [markdown]
# Было создано и добавлено на этапе 2.9 11 признаков:
# - `share_of_daytime_degree6` - возвели `share_of_daytime` в шестую степень
# - `share_of_user_clicks` - доля интенсивности кликов пользователя в зависимости от категории ads_activity, на 1000 кликов
# - `share_of_user_devices` - доля видов устройств на пользователя по primary_device, на 1000 устройств
# - `relative audience weight` - отношение числа пользователей, сгруппированных по возрасту и категории сайта, к общему числу пользователей сайта, на 10000 пользователей
# - Рассчитаем общий показатель `session_clicks_devices`, перемножим признаки: mean_session х share_of_user_clicks х share_of_user_devices
#
#
# **Результат**: метрика f1-weighted не изменилась. Осталась на уровне 0.39 - 0.40
#
# Ha ядрах rbf (0.52) и poly (0.47) метрики улучшились, но не достаточно.
#
# Добавим ещё несколько признаков (п.2.9), в результате метрики базовых моделей возрасли до **0,62**

# %% [markdown]
# ## Подбор гиперпараметров моделей

# %% [markdown]
# ### Определяем сетку гиперпараметров
# Определяем ключевые параметры, которые влияют на качество моделей LogisticRegression и SVC.
#
# Для этого создаём сетки гиперпараматров для моделей **lr**, **SVC**
#
# проверим с помощью линейных  и нелинейных вычислений.
#
# **Подбираем параметры для lr**

# %%
param_grid_lr_l2 = { 
    'classifier__C': [0.1, 1, 100], # Сила регуляризации 
    'classifier__class_weight': [
        #None, 
        'balanced'],
    'classifier__solver': ['lbfgs'] #, 'sag'], # Быстрые солверы для больших данных 
    #'classifier__max_iter': [500, 1000] # Чтобы избежать ошибки конвергенции 
}

# %%
param_grid_l1 = { 
    'classifier__penalty': ['l1', 'l2'], # Добавляем L1 
    'classifier__solver': ['saga'], # saga нужен для l1 
    'classifier__C': [0.01, 0.1, 1], # Уменьшаем диапазон C, он иначе влияет на L1 
    'classifier__max_iter': [1000, 2000] # Для 'saga' итераций нужно больше 
}

# %% [markdown]
# Применяем параметры для lr

# %%
lr_grid_search = GridSearchCV(
    estimator = lr_pipeline,
    param_grid=param_grid_lr_l2,
    cv=cv, 
    scoring='f1_macro',
    n_jobs=-1,
    verbose=2   # Чтобы видеть прогресс
)

# %%
lr_grid_search.fit(X_train, y_train)
display(f'Лучшие параметры: {lr_grid_search.best_params_}')
display(f'Лучшая метрика F1_macro на train: {lr_grid_search.best_score_:.4f}')
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# "Лучшие параметры: {'classifier__C': 100, 'classifier__class_weight': 'balanced', 'classifier__solver': 'lbfgs'}"
# 'Лучшая метрика F1_macro на train: 0.9837'

# %% [markdown]
# Сохраним лучшую модель линейной регрессии

# %%
best_lr = lr_grid_search.best_estimator_
display('Лучшая логистическая модель best_lr сохранена')
# Out:
# 'Лучшая логистическая модель best_lr сохранена'

# %% [markdown]
# **param_grid_lr_l2**
#
# "Лучшие параметры: {'classifier__C': 100, 'classifier__class_weight': 'balanced', 'classifier__solver': 'lbfgs'}"
# 'Лучшая метрика F1_macro на train: **0.9841**'
#
# **Замечание:** для lbfgs по умолчанию используется penalty=L2 (веса штрафуются, но не обнуляются) при росте C регуляризация (сила штрафа) ослабевает для LR.

# %% [markdown]
# **Подбираем параметры для SVC**

# %% [markdown]
# **Проверяем модель с линейным ядром.** Пока в модели используем для этобго более быстрый и легкий класс LinearSVC

# %%
svc_param_grid = { 'classifier__C': [0.01, 0.1, 1], # Сила регуляризации 
                   'classifier__class_weight': ['balanced'] }

# %%
svc_grid_search = GridSearchCV(
    estimator = svc_pipeline,
    param_grid=svc_param_grid,
    cv=cv, 
    scoring='f1_macro', 
    n_jobs=-1,
    verbose=2   
)

# %%
svc_grid_search.fit(X_train, y_train)
display(f'Лучшие параметры: {svc_grid_search.best_params_}')
display(f'Лучшая метрика F1_macro на train: {svc_grid_search.best_score_:.4f}')
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# "Лучшие параметры: {'classifier__C': 1, 'classifier__class_weight': 'balanced'}"
# 'Лучшая метрика F1_macro на train: 0.9782'

# %% [markdown]
# Сохраним лучшую SVC модель

# %%
best_svc = svc_grid_search.best_estimator_
display('Лучшая SVC модель best_svc сохранена')
# Out:
# 'Лучшая SVC модель best_svc сохранена'

# %% [markdown]
# "Лучшие параметры: {'classifier__C': 1, 'classifier__class_weight': 'balanced'}"
# 'Лучшая метрика F1_macro на train: **0.9794**'
#
#
# Проверим на ядре poly - для поиска нелинейных взаимосвязей

# %% [markdown]
# ##### Вычисления на ядре rbf  train

# %% [markdown]
# Обучим новый пайплайн svc  на новой выборке X_train, чтобы посмотреть работу ядра rbf  и определить лучшие параметры

# %% [markdown]
# **rbf полный**

# %%
svc_for_RFE = LinearSVC(
    C=1.0,              
    class_weight='balanced'
)


final_svc_classifier = SVC(
    kernel='rbf', 
    C=1.0,              
    gamma='scale',      
    class_weight='balanced',
    probability=False
)

svm_rbf_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('RFE', RFE(
        estimator = svc_for_RFE,
        n_features_to_select=20,
        step=1
    )),
    ('classifier', final_svc_classifier)
])

# %%
svm_rbf_pip = svm_rbf_pipeline.fit(X_train, y_train)
display('Обучение svm_rbf_pipeline ...')
# Out:
# 'Обучение svm_rbf_pipeline ...'

# %%
param_grid_rbf_basic = {
    'classifier__C': [0.1, 1, 10, 100],
    'classifier__gamma': ['scale', 0.1, 1], 
    'classifier__class_weight': ['balanced']
}

# %%
param_grid_rbf_detailed = {
    'classifier__C': np.logspace(-3, 2, 6),      # Массив: [0.001, 0.01, 0.1, 1, 10, 100]
    'classifier__gamma': np.logspace(-3, 0, 4),  # Массив: [0.001, 0.01, 0.1, 1.0]
    'classifier__class_weight': ['balanced'],
    'classifier__kernel': ['rbf']                # Можно указать явно для читаемости
}

# %%
svc_grid_search_rbf2 = GridSearchCV(
    estimator = svm_rbf_pipeline,
    param_grid= param_grid_rbf_detailed,
    cv=cv, 
    scoring='f1_macro',
    n_jobs=-1,
    verbose=2   # Чтобы видеть прогресс
)

# %%
svc_grid_search_rbf2.fit(X_train, y_train)
display(f'Лучшие параметры: {svc_grid_search_rbf2.best_params_}')
display(f'Лучшая метрика F1_macro на train: {svc_grid_search_rbf2.best_score_:.4f}')
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# "Лучшие параметры: {'classifier__C': np.float64(100.0), 'classifier__class_weight': 'balanced', 'classifier__gamma': np.float64(0.1), 'classifier__kernel': 'rbf'}"
# 'Лучшая метрика F1_macro на train: 0.9767'

# %% [markdown]
# Сохраним лучшую rbf модель

# %%
best_rbf = svc_grid_search_rbf2.best_estimator_
display('Лучшая rbf best_rbf сохранена')
# Out:
# 'Лучшая rbf best_rbf сохранена'

# %% [markdown]
# **param_grid_rbf_detailed**
# "Лучшие параметры: {'classifier__C': np.float64(100.0), 'classifier__class_weight': 'balanced', 'classifier__gamma': np.float64(0.01), 'classifier__kernel': 'rbf'}"
# 'Лучшая метрика F1_macro на train: 0.9756'

# %% [markdown]
# **Poly**

# %%
svc2_for_RFE = SVC(
    kernel='linear',
    C=1.0,              
    class_weight='balanced',
    probability=False,
    random_state=RANDOM_SEED
)
final_svc2_classifier = SVC(
    kernel='linear',
    C=1.0,              
    class_weight='balanced',
    probability = False,
    random_state=RANDOM_SEED
)

# %%
svc2_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('features_selector', RFE(
        estimator = svc2_for_RFE,
        n_features_to_select=20,
        step=1,
        verbose=2
    )),
    ('classifier', final_svc2_classifier)
])

# %%
svc2_pipeline.fit(X_train, y_train)
display('Обучение svc2_pipeline ...')
# Out:
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# 'Обучение svc2_pipeline ...'

# %% [markdown]
# Получаем список отобранных признаков после RFE

# %% [raw]
# rfe_step = svc2_pipeline.named_steps['features_selector']
# feature_names = rfe_step.get_feature_names_out()

# %%
display(feature_names)
# Out:
# array(['share_of_visited_category_03', 'share_of_visited_category_08',
#        'share_of_visited_category_13', 'share_of_visited_category_18',
#        'count_session_id', 'share_daytime_вечер', 'share_daytime_день',
#        'share_daytime_утро', 'cloud_usage', 'share_of_visited_websites',
#        'share_of_user_clicks', 'share_of_user_devices', 'users_activity',
#        'character_age0', 'character_age1', 'character_age2',
#        'character_age3', 'character_age4', 'character_ctr2',
#        'character_ctr3', 'character_ctr4', 'max_active_daytime_вечер',
#        'max_active_daytime_день', 'max_active_daytime_утро',
#        'ads_activity_очень редко', 'ads_activity_очень часто',
#        'ads_activity_редко', 'ads_activity_умеренно',
#        'ads_activity_часто', 'primary_device_ноутбук',
#        'primary_device_пк', 'primary_device_планшет',
#        'primary_device_смартфон', 'surf_depth_глубоко',
#        'surf_depth_поверхностно', 'surf_depth_средне'], dtype=object)

# %% [markdown]
# теперь применим сетку

# %%
svc_param_grid_poly = { 
    'classifier__kernel': ['poly'], 
    'classifier__C': [0.1, 1, 10], 
    'classifier__degree': [2, 3], 
    'classifier__gamma': ['scale', 0.1], 
    'classifier__coef0': [0, 1], 
    'classifier__class_weight': ['balanced'] 
    }

# %%
svc_grid_search_poly = GridSearchCV(
    estimator = svc2_pipeline,
    param_grid=svc_param_grid_poly,
    cv=cv, 
    scoring='f1_macro',
    n_jobs=-1,
    verbose=2   
)

# %%
svc_grid_search_poly.fit(X_train, y_train)
display(f'Лучшие параметры: {svc_grid_search_poly.best_params_}')
display(f'Лучшая метрика F1_macro на train: {svc_grid_search_poly.best_score_:.4f}')
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# "Лучшие параметры: {'classifier__C': 10, 'classifier__class_weight': 'balanced', 'classifier__coef0': 1, 'classifier__degree': 2, 'classifier__gamma': 0.1, 'classifier__kernel': 'poly'}"
# 'Лучшая метрика F1_macro на train: 0.9806'

# %% [markdown]
# "Лучшие параметры: {'classifier__C': 10, 'classifier__class_weight': 'balanced', 'classifier__coef0': 1, 'classifier__degree': 2, 'classifier__gamma': 'scale', 'classifier__kernel': 'poly'}"
# 'Лучшая метрика F1_macro на train: **0.9685**'

# %% [markdown]
# Сохраним лучшую модель

# %%
best_poly = svc_grid_search_poly.best_estimator_
display('Лучшая poly модель best_poly сохранена ')
# Out:
# 'Лучшая poly модель best_poly сохранена '

# %% [markdown]
# **Выведем результаты по моделям в датафрейм**

# %%
results_data = {
    'model_name': [
        'Linear_basa', 
        'SVC_Linear_basa', 
        'Linear_GridSearch', 
        'SVC_Linear_GridSearch', 
        'SVC_Poly', 'SVC_RBF'
    ],
    'best_score f1_macro': [
        mean_f1_lr,
        mean_f1_svc, 
        round(lr_grid_search.best_score_, 4), 
        round(svc_grid_search.best_score_, 4),
        round(svc_grid_search_poly.best_score_, 4),
        round(svc_grid_search_rbf2.best_score_, 4)
    ],
    'best_params': [
        {},
        {},
        lr_grid_search.best_params_, 
        svc_grid_search.best_params_,
        svc_grid_search_poly.best_params_,
        svc_grid_search_rbf2.best_params_
    ]
}

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b> Начало исправления кода вывода словаря по замечанию (оно ниже расположено)
# </div>

# %% [markdown]
# Приведём ячейки к строкам, чтобы было единообразие и убирём префикс "classifier__". Напишем для этого функцию **format_params**

# %%
def format_params(params):
    '''
    params - словарь, который надо преобразовать
    '''
    if not params or pd.isna(params):  
        return '-'

    if isinstance(params, str):
        return params
        
    param_strings =[f"{k}={v}" for k, v in params.items()]
    result_string = ", ".join(param_strings).replace('classifier__', '')
    return result_string

for i in range(len(results_data['best_params'])):
    results_data['best_params'][i] = format_params(results_data['best_params'][i])
    
df_models_results = pd.DataFrame(results_data)

# %% [markdown]
# Добавим вывод о рекомендации в отчет. А также выбирем лучшую из моделей.
#
# Устанавливаем опцию option_context('display.max_colwidth', None), чтобы в таблице выводилась вся информация (не обрезалась часть, как было в столбце "best_params")

# %%
def prod_or_not(score):
    '''
    функция выдает результат: рекомендовать или нет в продакшен
    score - метрика, которую проверяем
    '''
    if pd.isna(score): 
        return 'Нет данных'
        
    if score < 0.75:
        return f'НЕЛЬЗЯ рекомендовать в продакшен'
    else:
        return f'РЕКОМЕНДОВАТЬ в продакшен'

df_models_results['Prodacshen, метрика>=0.75']=df_models_results['best_score f1_macro'].apply(prod_or_not)    


display('='*115)
display(f'Метрики и параметры полученных моделей:' )
display('='*115)
with pd.option_context('display.max_colwidth', None): 
    display(df_models_results)

display('='*115)


display('='*115)
display("Лучшая модель")
display('='*115)

mask = df_models_results['best_score f1_macro'] == df_models_results['best_score f1_macro'].max()

best_model_df = df_models_results[mask]
display(best_model_df)
display('='*115)
# Out:
# '==================================================================================================================='
# 'Метрики и параметры полученных моделей:'
# '==================================================================================================================='
#               model_name  best_score f1_macro  \
# 0            Linear_basa             0.968564
# 1        SVC_Linear_basa             0.978171
# 2      Linear_GridSearch             0.983700
# 3  SVC_Linear_GridSearch             0.978200
# 4               SVC_Poly             0.980600
# 5                SVC_RBF             0.976700
#
#                                                               best_params  \
# 0                                                                       -
# 1                                                                       -
# 2                              C=100, class_weight=balanced, solver=lbfgs
# ...

# %% [markdown]
# Таким образом, все модели можно рекомендовать в продакшен, поскольку метрики на уровне 0,97 - 0,98
#
# Лучшей моделью с небольшим отрывом стала модель **логистической регрессии**, с ниалучшим параметром регуляризации C=100 для сбалансированнной выборки: **f1-macro=0.9842**
#
# То есть наша (наши) модели угадывают практически без ошибок возраст клиента.
#
# Заметим'📝': высокие метрики у базовой модели (0,966) объясняются введением дополнительных рассчетных признаков в п.2.9.
#
# Если удалить признаки из п.2.9 базовая модель будет на уровне 0,62. Тогда дальнейшее исследование покажет эффективность применения нелинейных вычислений: макро-усреднённые метрики в моделях, с ядрами **poly** и **rbf** будут на приемлемом для продакшена уровне с метриками f1_macro 0,8 (poly чуть выше)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b> Конец исправления кода вывода словаря по замечанию (оно ниже расположено)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ошибка:</b> Итоговая сравнительная таблица моделей приведена только в терминах f1_weighted. Нигде не выведено и не сопоставлено с порогом 0.75 значение F1-macro на кросс-валидации — ключевой критерий задания при выборе лучшей модели невозможно проверить по этой таблице.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b> Исправления выше
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Изменения:</b>
#
# - Переписан код вывода словаря ...
# - добавлен столбик с проверкой каждой модели
# - выведена лучшая по метрикам из всех моделей
# - новый вывод по результатам
# </div>

# %% [markdown]
# ### Обучение лучшей модели и получение метрик

# %% [markdown]
# Обучим лучшую модель на обучающей выборке **train**.
#
# Лучшей стала модель логистической регрессии **best_lr**, её и обучим

# %%
best_lr.fit(X_train, y_train)
display('Обучение завершено')
# Out:
# 'Обучение завершено'

# %% [markdown]
# 1. Считаю метрики на X_train, y_train с помощью кросс-валидации
#
# Используем predict для оценки на val и test

# %%
poly_sample_metrics = { 
    'f1_macro': 'f1_macro', 
    'precision_macro': 'precision_macro', 
    'recall_macro': 'recall_macro' }


scores_poly = cross_validate(
    estimator=best_lr,
    X=X_train, 
    y=y_train,
    cv=cv, 
    scoring=poly_sample_metrics,
    return_train_score=True, 
    n_jobs=-1 
)

# %% [markdown]
# Выводим метрики

# %%
mean_f1 = np.mean(scores_poly['test_f1_macro']) 
std_f1 = np.std(scores_poly['test_f1_macro']) 

mean_precision = np.mean(scores_poly['test_precision_macro']) 
mean_recall = np.mean(scores_poly['test_recall_macro']) 

display(f'F1-macro: {mean_f1:.4f} (+/- {std_f1:.4f})') 
display(f'Precision macro: {mean_precision:.4f}') 
display(f'Recall macro: {mean_recall:.4f}')
# Out:
# 'F1-macro: 0.9837 (+/- 0.0031)'
# 'Precision macro: 0.9834'
# 'Recall macro: 0.9842'

# %% [markdown]
# Метрики на обучающей выборки с помощью кросс-валидации:
#
# 'F1-macro: 0.9842 (+/- 0.0044)'
# 'Precision macro: 0.9836'
# 'Recall macro: 0.9850'
#
# Таким образом, на train модель практически не ошибается

# %%
y_train_pred = best_lr.predict(X_train)

# %% [markdown]
# 2. Применим готовую модель для получения меток классов на val:

# %%
y_val_pred = best_lr.predict(X_val)

# %%
print('Classification report,  val:\n', classification_report(y_val, y_val_pred))
# Out:
# Classification report,  val:
#                precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97       171
#            1       0.99      0.98      0.99       103
#            2       0.99      0.99      0.99       288
#            3       0.99      0.98      0.98       251
#            4       0.99      1.00      0.99       353
#
#     accuracy                           0.99      1166
#    macro avg       0.99      0.98      0.98      1166
# weighted avg       0.99      0.99      0.99      1166

# %% [markdown]
# Напишем функцию *f1_macro_model_metrics*, которая по истинным меткам *y* и предсказанным, выводит словарь с метриками

# %%
def f1_macro_model_metrics(y_true, y_pred):
    metrics = {
        'precision_macro': precision_score(y_true, y_pred, average = 'macro'),
        'recall_macro': recall_score(y_true, y_pred, average = 'macro'),
        'f1_macro': f1_score(y_true, y_pred, average = 'macro'),
        'confusion_matrix': confusion_matrix(y_true, y_pred)
    }
    return metrics

# %% [markdown]
# Посчитаем результаты для моделей

# %%
results_train = f1_macro_model_metrics(y_train, y_train_pred)
results_val = f1_macro_model_metrics(y_val, y_val_pred)

# %% [markdown]
# Результаты сохраним в датафрейм *df_results_train_val*

# %%
df_results_train_val = pd.DataFrame({
    'train': {k: v for k, v in results_train.items() if k != 'confusion_matrix'},
    'val': {k: v for k, v in results_val.items() if k != 'confusion_matrix'}
    
})

print('='*110)
print('Метрики precision, recall, f1 лучшей модели best_poly на train и val: ')
print('='*110)
print(df_results_train_val)
print('='*110)
# Out:
# ...
# Метрики precision, recall, f1 лучшей модели best_poly на train и val:
# ...
#                     train       val
# precision_macro  0.987017  0.985078
# recall_macro     0.987879  0.984483
# f1_macro         0.987442  0.984748
# ...

# %% [markdown]
# Построим матрицу ошибок

# %%
confusion_matrix_val = results_val['confusion_matrix']

# %%
print(confusion_matrix_val)
# Out:
# [[168   0   2   1   0]
#  [  2 101   0   0   0]
#  [  2   1 284   1   0]
#  [  2   0   0 245   4]
#  [  0   0   0   1 352]]

# %% [markdown]
# Строим тепловую карту матрицы ошибок

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(
    confusion_matrix_val, 
    annot=True,          
    fmt='d',             
    cmap='YlGnBu',       
    linewidths=0.5,
    linecolor='gray',
    cbar=True,
    square=True          
)

plt.suptitle('Confusion Matrix - best_poly val', fontsize=14, y=1.05)
plt.xlabel('Predicted Label', fontsize=12)
plt.ylabel('True Label', fontsize=12)


plt.tight_layout()
plt.show()

# %% [markdown]
# Судя по карте, модель хорошо определяем и мало путает. Больше всего ошибок:
# - третий класс с четвертым
# - четвертый с третьим
#
# Метрика f1_macro хорошо работает со всеми классами, даже с более редкими классами **1** и **0**

# %% [markdown]
# **Веса модели**
#
# Поскольку ядро - linear, то выберем признаки с помошью **coef_[0]**.

# %%
classifier = best_lr.named_steps['classifier']

selected_feature_names = best_lr.named_steps['features_selector'].get_feature_names_out()

weights = classifier.coef_[0]

# %% [markdown]
# Собираю колонки и веса в один датафрейм

# %%
feature_importance_df = pd.DataFrame({
    'feature': selected_feature_names,
    'weight': weights
})

# %% [markdown]
# Сортирую и вывожу

# %%
feature_importance_df['abs_weight'] = feature_importance_df['weight'].abs()
feature_importance_df_lr = feature_importance_df.sort_values('abs_weight', ascending=False).drop(columns='abs_weight')

print(feature_importance_df_lr.head(25))
# Out:
#                          feature     weight
# 9                 character_age1 -27.303593
# 10                character_age2 -16.320342
# 14                character_ctr3 -14.990956
# 13                character_ctr2 -13.051422
# 5                    cloud_usage  10.728449
# 7                 users_activity  -6.895875
# 8                 character_age0   5.872362
# 15                character_ctr4  -5.609100
# 11                character_age3  -5.306548
# 3             share_daytime_день  -1.765525
# 4             share_daytime_утро  -1.567866
# 18      ads_activity_очень часто   0.800108
# 6          share_of_user_devices   0.652649
# 17      ads_activity_очень редко   0.643612
# 19            ads_activity_редко  -0.643022
# 1   share_of_visited_category_18   0.567373
# 12                character_age4   0.517056
# 2            share_daytime_вечер  -0.224056
# 16       max_active_daytime_день  -0.161745
# 0   share_of_visited_category_13  -0.016614

# %% [markdown]
# Определили наиболее весомые признаки для определения возраста пользователя являются:
# - character_age1-2
# - character_ctr2-3
# - cloud_usage
# - users_activity
# - character_age0, 3
# - ads_activity_очень часто
# - primary_device_планшет и др.
#
# Лидеры - первые три: **character_age, character_ctr, cloud_usage**

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Хорошая дополнительная работа — оценка важности признаков через permutation importance с агрегацией OHE-столбцов обратно к исходным признакам, есть интерпретация результатов.
# </div>

# %% [markdown]
# ## Подготовка артефактов модели для внедрения

# %% [markdown]
# Создадим функцию для получения датафрейма new_df_ds_s13_visits по данным df_ds_s13_visits

# %%
def transformation_df_ds_s13_visits (tmp):
    '''
    преобразовывает df_ds_s13_visits в новый датафрейм (по пользователю, не сессии).
    Для этого по df_ds_s13_visits рассчитываются новые групповые показатели по user_id,
    транспонируются столбцы,
    объединяются в единый датафрейм new_df_ds_s13_visits
    '''
    # функция отбирает и переименовывает столбцы у рассчётной таблицы
    def new_columns(table, table_name):
        new_name = []
        for col in table.columns:
            if col == 'user_id':
                new_name.append(col)
            else:
                if table_name == 'share_of_visited_websites':
                    clean_col = str(col).replace(' ', '_').replace('share_of_visited_websites_', '') 
                    new_name.append(f'share_of_visited_{clean_col}')
                elif table_name == 'mean_session':
                    base_str = str(col).split('.')[0]
                    dt_obj = pd.to_datetime(base_str)
                    formatted = dt_obj.strftime('%Y-%m-%d_%H:%M:%S')
                    new_name.append(f'mean_session_{formatted}')
                    
                else:
                    col_clean = col.replace(' ', '_')
                    new_name.append(f'{table_name}_{col_clean}')
  
        table.columns = new_name
        return table   

    tmp0 = tmp.copy()
    tmp0['date'] = pd.to_datetime(tmp0['date'])   
    tmp0['dayweek'] = tmp0['date'].dt.dayofweek
# Расчёт показателя (`share_of_visited_websites / share_of_visited_category01 ...`)
    visits = pd.pivot_table(
        tmp0, 
        values='session_id', 
        index= 'user_id' ,
        columns='website_category', 
        aggfunc='count', 
        fill_value=0 
        )
    count_visits = (pd.pivot_table(
        tmp0, 
        values='session_id', 
        index= 'user_id' ,
        aggfunc='count', 
        fill_value=0
        )
        .iloc[:, 0] 
    )
    share_of_visited_websites = visits.div(count_visits, axis=0).fillna(0).round(3)
    new_columns(share_of_visited_websites, 'share_of_visited_websites')
    
    # Расчёт показателя (share_of_daytime)
    daytime = pd.pivot_table(
        tmp0, 
        values='session_id', 
        index= 'user_id' ,
        columns='daytime', 
        aggfunc='count', 
        fill_value=0 
        )
    
    share_daytime = daytime.div(count_visits, axis=0).fillna(0).round(3)
    
    share_daytime.reset_index()
    new_columns(share_daytime, 'share_daytime')

    # Расчёт показателя (mean_session)
    date = pd.pivot_table(
        tmp0, 
        values='session_id', 
        index= 'user_id' ,
        columns='date', 
        aggfunc='count', 
        fill_value=0
        )
    date.columns = [str(c).split('.')[0] for c in date.columns]
    mean_session = date.div(count_visits, axis=0).fillna(0).round(3)
    mean_session.reset_index(inplace=True)
    new_columns(mean_session, 'mean_session')

    # Расчёт показателя (max_active_daytime)
    max_daytime = daytime.idxmax(axis=1).reset_index(name='max_active_daytime')

    # объединяем маленькие таблички в одну итоговую
    list_visits_tables = [count_visits, share_daytime, mean_session, max_daytime]
    new_df_ds_s13_visits = share_of_visited_websites

    for tab in list_visits_tables:
        new_df_ds_s13_visits = new_df_ds_s13_visits.merge(tab, on='user_id', how='left')
    
    new_df_ds_s13_visits.rename(columns={'session_id': 'count_session_id'}, inplace=True)
            
    return new_df_ds_s13_visits

# %% [markdown]
# Создадим функцию для объединения датафреймов и создания признаков

# %%
def merge_df (tmp0, tmp1, tmp2, tmp3, tmp4, tmp5):
    '''
    tmp0, tmp1, tmp2, tmp3, tmp4, tmp5 - датафреймы, которые надо объединить
    user_id - поле, по которому объединяются датафреймы

    Создаёт новые признаки
    '''
    df=tmp0.copy()
    for dataframe in [tmp1, tmp2, tmp3, tmp4, tmp5]:
        df=df.merge(dataframe, on='user_id', how='left')
    
    # Создаю 11 новых показателей
    # share_of_visited_websites - Доля интернет-активности пользователя в общей посещаемости сайтов пользователями
    df['share_of_visited_websites'] = df['count_session_id'] / df['count_session_id'].sum()*1000

    # share_of_user_clicks - индекс кликабельности пользователя 
    count_ads_activity_user=df.groupby(['ads_activity', 'user_id'])['user_id'].count()
    share_of_user_clicks=((count_ads_activity_user/df.groupby(['ads_activity'])['user_id'].count())*1000).reset_index(name='share_of_user_clicks')
       #объединяем share_of_user_clicks с датафреймом df
    df = df.merge(share_of_user_clicks, on=['ads_activity', 'user_id'], how='left')

    # share_of_user_devices - доля видов устройств на пользователя по primary_device, на 1000 устройств
    count_primary_device=df.groupby(['primary_device'])['user_id'].count()
    count_primary_device_user=df.groupby(['primary_device', 'user_id'])['age_category'].count()
    share_of_user_devices=((count_primary_device_user/count_primary_device)*1000).reset_index(name='share_of_user_devices')
    df = df.merge(share_of_user_devices, on=['primary_device', 'user_id'], how='left')

    # users_activity
    df['users_activity'] = (df['age_category']*df['share_of_user_clicks']*df['share_of_user_devices'] * df['share_of_visited_websites']).round(3)

    # Преобразование типа поля cloud_usage
    most_frequent = df['cloud_usage'].mode().iloc[0] if not df['cloud_usage'].empty else 0 
    df['cloud_usage'] = df['cloud_usage'].fillna(most_frequent).astype(int)

    sum_age_category = pd.pivot_table(
        df, 
        values= ['users_activity', 'cloud_usage'],
        index= 'user_id',
        columns='age_category',
        aggfunc='sum', 
        fill_value=0
     )
    
    sum_age_category.columns
    new_col=[]
    i=0
    j=0
    for col in sum_age_category.columns:
        if 'cloud_usage' in col:
            new_col.append(f'cloud_usage_{i}')
            i=i+1
        else:
            new_col.append(f'users_activity_{j}')
            j=j+1 

    sum_age_category.columns=new_col   


    

    # character_age0, character_age1, character_age2, character_age3, character_age4 - обобщающие показатели
    for i in range(5):
        sum_age_category[f'age{i}'] = (sum_age_category[f'cloud_usage_{i}'] + sum_age_category[f'users_activity_{i}'])
        sum_age_category[f'character_age{i}'] = (sum_age_category[f'age{i}']/sum_age_category[f'age{i}'].sum()*1000).round(3)
    
    add_colls = ['character_age0',
           'character_age1', 'character_age2', 'character_age3', 'character_age4']
    df=df.merge(sum_age_category[add_colls], on='user_id', how='left')

    # character_ctr0, character_ctr1, character_ctr2, character_ctr3, character_ctr4
    sum_ads_activity = pd.pivot_table(
        df, 
        values= ['users_activity', 'cloud_usage'],
        index= 'user_id',
        columns='ads_activity',
        aggfunc='sum', 
        fill_value=0
    )
    i=0
    j=0
    new_col2=[]
    for col in sum_ads_activity.columns:
        if 'cloud_usage' in col:
            new_col2.append(f'cloud_usage_{i}')
            i=i+1
        else:
            new_col2.append(f'users_activity_{j}')
            j=j+1 

    sum_ads_activity.columns=new_col2  

    for i in range(5):
        sum_ads_activity[f'ctr{i}'] = (sum_ads_activity[f'cloud_usage_{i}'] + sum_ads_activity[f'users_activity_{i}'])
        sum_ads_activity[f'character_ctr{i}'] = (sum_ads_activity[f'ctr{i}']/sum_ads_activity[f'ctr{i}'].sum()*1000).round(3)

    add_colls2 = ['character_ctr0','character_ctr1','character_ctr2',
                  'character_ctr3','character_ctr4']
    df=df.merge(sum_ads_activity[add_colls2], on='user_id', how='left')
    # Удаляем столбцы по этапу корреляций, а также user_id
    cols_to_drop = ['character_ctr0', 'character_ctr1', 'mean_session_2025-11-01 00:00:00',
                    'mean_session_2025-11-05 00:00:00', 'mean_session_2025-11-08 00:00:00',
                    'mean_session_2025-11-10 00:00:00', 'user_id']
    df=df.drop(columns=cols_to_drop, errors='ignore')

    # Разделим на X и y
    X=df.drop(columns='age_category')
    y=df['age_category']
    
    return X, y

# %% [markdown]
# Сохраняю пайплайн предобработки

# %%
joblib.dump(preprocessor, 'preprocessor.joblib')
# Out:
# ['preprocessor.joblib']

# %% [markdown]
# Сохраняю финальную модель

# %%
joblib.dump(best_lr, 'best_lr.joblib')
# Out:
# ['best_lr.joblib']

# %% [markdown]
# Сохраняю информацию о выбранных признаках

# %%
#import json

# feature_names у меня получены выше:
# feature_names = rfe_step.get_feature_names_out()

with open('selected_features.json', 'w', encoding='utf-8') as f:
    # Преобразуем numpy array со строками в обычный список Python
    json.dump(feature_names.tolist(), f, ensure_ascii=False, indent=4)

print("Список признаков сохранен в selected_features.json")
# Out:
# Список признаков сохранен в selected_features.json

# %% [markdown]
# ### Проверяю работоспособность кода

# %% [markdown]
# Сгенерируем новые тестовые записи по 6 таблицам

# %% [markdown]
# Применяю функцию **transformation_df_ds_s13_visits** для преобразования таблицы

# %%
np.random.seed(42)
N_USERS = 1500  # число записей


ADS_ACTIVITY_CATS = ['умеренно', 'очень редко', 'часто', 'редко', 'очень часто']
PRIMARY_DEVICE_CATS = ['ноутбук', 'планшет', 'смартфон', 'пк']
SURF_DEPTH_CATS = ['средне', 'поверхностно', 'глубоко']
MAX_ACTIVE_DAYTIME_CATS = ['вечер', 'день', 'утро', 'ночь']
WEBSITE_CATEGORY_CATS = [
    'category 17', 'category 19', 'category 18', 'category 20', 'category 05',
    'category 12', 'category 03', 'category 15', 'category 10', 'category 06',
    'category 04', 'category 09', 'category 01', 'category 11', 'category 07',
    'category 14', 'category 08', 'category 13', 'category 02', 'category 16'
]
DATE_CATS = [f'2025-11-{i:02d}' for i in range(1, 15)]
AGE_CATS = [0, 1, 2, 3, 4]

# Заданное распределение возрастов (в долях единицы): 
# Группа 0 – 9%, группа 1 – 15%, группа 2 – 25%, группа 3 – 22%, группа 4 – 29%
AGE_PROBS = [0.09, 0.15, 0.25, 0.22, 0.29]  

user_ids = [str(uuid.uuid4()) for _ in range(N_USERS)]

df_ds_s13_users_test = pd.DataFrame({
    'user_id': user_ids,
    'age_category': np.random.choice(AGE_CATS, size=N_USERS, p=AGE_PROBS)
})

df_ads_activity_test = pd.DataFrame({
    'user_id': user_ids,
    'ads_activity': np.random.choice(ADS_ACTIVITY_CATS, size=N_USERS, p=[0.25, 0.15, 0.25, 0.20, 0.15])
})

df_primary_device_test = pd.DataFrame({
    'user_id': user_ids,
    'primary_device': np.random.choice(PRIMARY_DEVICE_CATS, size=N_USERS, p=[0.30, 0.10, 0.40, 0.20])
})

df_surf_depth_test = pd.DataFrame({
    'user_id': user_ids,
    'surf_depth': np.random.choice(SURF_DEPTH_CATS, size=N_USERS, p=[0.40, 0.35, 0.25])
})

df_cloud_usage_test = pd.DataFrame({
    'user_id': user_ids,
    'cloud_usage': np.random.choice([True, False], size=N_USERS, p=[0.35, 0.65])
})


visits_per_user = np.random.poisson(lam=3, size=N_USERS) + 1 
visits_per_user[visits_per_user > 12] = 12  # Ограничиваем для контроля размера файла

all_visits = []
for uid, n in zip(user_ids, visits_per_user):
    dates = np.random.choice(DATE_CATS, size=n)
    daytimes = np.random.choice(MAX_ACTIVE_DAYTIME_CATS, size=n)
    session_ids = [str(uuid.uuid4()) for _ in range(n)]
    website_cats = np.random.choice(WEBSITE_CATEGORY_CATS, size=n)
    
    for i in range(n):
        all_visits.append({
            'date': dates[i],
            'daytime': daytimes[i],
            'session_id': session_ids[i],
            'user_id': uid,
            'website_category': website_cats[i]
        })

df_ds_s13_visits_test = pd.DataFrame(all_visits)

# %% [markdown]
# Запускаем функции

# %%
new_df_ds_s13_visits_test = transformation_df_ds_s13_visits (df_ds_s13_visits_test)
X_new_test, y_new_test =merge_df(new_df_ds_s13_visits_test, df_ds_s13_users_test, df_cloud_usage_test, df_ads_activity_test, df_primary_device_test, df_surf_depth_test)

# %%
display(X_new_test.shape, y_new_test.shape)
# Out:
# (1500, 56)
# (1500,)

# %%
X_new_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 56 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   share_of_visited_category_01      1500 non-null   float64
#  1   share_of_visited_category_02      1500 non-null   float64
#  2   share_of_visited_category_03      1500 non-null   float64
#  3   share_of_visited_category_04      1500 non-null   float64
#  4   share_of_visited_category_05      1500 non-null   float64
#  5   share_of_visited_category_06      1500 non-null   float64
#  6   share_of_visited_category_07      1500 non-null   float64
#  7   share_of_visited_category_08      1500 non-null   float64
#  8   share_of_visited_category_09      1500 non-null   float64
#  9   share_of_visited_category_10      1500 non-null   float64
#  10  share_of_visited_category_11      1500 non-null   float64
# ...

# %% [markdown]
# 1. Проверка: загружаю модель, загружаю данные по новоым клиентам и делаю предсказание
#
# **Проверяю модель на тестовой выборке test**

# %%
loaded_pipe = joblib.load('preprocessor.joblib')
result = loaded_pipe.fit_transform(X_new_test, y_new_test) #
print(f'Препроцессинг новых данных X_new_test: {result.info()}')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 64 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   share_of_visited_category_01      1500 non-null   float64
#  1   share_of_visited_category_02      1500 non-null   float64
#  2   share_of_visited_category_03      1500 non-null   float64
#  3   share_of_visited_category_04      1500 non-null   float64
#  4   share_of_visited_category_05      1500 non-null   float64
#  5   share_of_visited_category_06      1500 non-null   float64
#  6   share_of_visited_category_07      1500 non-null   float64
#  7   share_of_visited_category_08      1500 non-null   float64
#  8   share_of_visited_category_09      1500 non-null   float64
#  9   share_of_visited_category_10      1500 non-null   float64
#  10  share_of_visited_category_11      1500 non-null   float64
# ...

# %% [markdown]
# Проверяю модель best_lr

# %%
estimator_test = joblib.load('best_lr.joblib')

# %%
lr_metrics = { 
    'f1_macro': 'f1_macro', 
    'precision_macro': 'precision_macro', 
    'recall_macro': 'recall_macro' }


scores_lr_basa = cross_validate(
    estimator=estimator_test,
    X=X_new_test,
    y=y_new_test,
    cv=cv, 
    scoring=lr_metrics,
    return_train_score=True, 
    n_jobs=-1 
)

# %%
mean_f1_lr_test = np.mean(scores_lr_basa['test_f1_macro']) 
std_f1_test = np.std(scores_lr_basa['test_f1_macro']) 

mean_precision_test = np.mean(scores_lr_basa['test_precision_macro']) 
mean_recall_test = np.mean(scores_lr_basa['test_recall_macro']) 

display(f'F1 macro: {mean_f1_lr_test:.4f} (+/- {std_f1_test:.4f})') 
display(f'Precision macro: {mean_precision_test:.4f}') 
display(f'Recall macro: {mean_recall_test:.4f}')
# Out:
# 'F1 macro: 0.9980 (+/- 0.0024)'
# 'Precision macro: 0.9981'
# 'Recall macro: 0.9980'

# %% [markdown]
# Получим метки классов на test

# %%
y_test_pred = best_lr.predict(X_new_test)

# %%
print('Classification report,  test:\n', classification_report(y_new_test, y_test_pred))
# Out:
# Classification report,  test:
#                precision    recall  f1-score   support
#
#            0       1.00      0.68      0.81       147
#            1       0.94      0.99      0.96       233
#            2       1.00      0.99      1.00       341
#            3       0.99      0.98      0.99       348
#            4       0.92      1.00      0.96       431
#
#     accuracy                           0.96      1500
#    macro avg       0.97      0.93      0.94      1500
# weighted avg       0.96      0.96      0.96      1500

# %% [markdown]
# **Проверяем признаки**

# %%
features_df = pd.read_json('selected_features.json')

print(f'Выводим первые 20 признаков: {features_df.head(20)}')
display('='*120)
display('Список всех сохранённых признаков: ') 
display('='*120)
display(f'{features_df.squeeze().tolist()}') 
display('='*120)
# Out:
# Выводим первые 20 признаков:                                0
# 0   share_of_visited_category_03
# 1   share_of_visited_category_08
# 2   share_of_visited_category_13
# 3   share_of_visited_category_18
# 4               count_session_id
# 5            share_daytime_вечер
# 6             share_daytime_день
# 7             share_daytime_утро
# 8                    cloud_usage
# 9      share_of_visited_websites
# 10          share_of_user_clicks
# 11         share_of_user_devices
# 12                users_activity
# 13                character_age0
# 14                character_age1
# 15                character_age2
# 16                character_age3
# 17                character_age4
# 18                character_ctr2
# 19                character_ctr3
# '========================================================================================================================'
# 'Список всех сохранённых признаков: '
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ошибка:</b> Проверка сохранённых артефактов выполняется на уже готовых X_test/X_val, а не на "сырых" CSV, пропущенных через функцию merge_df (которая как раз создавалась для продакшена). Датафрейм df_new, полученный через merge_df, создан, но ни разу не прогнан через модель — то есть предсказания артефактов не сверены со сквозным пайплайном "с нуля", как того требует критерий проверки.
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Совет:</b> Сохранение preprocessor.joblib отдельно от best_poly.joblib избыточно: препроцессор уже является первым шагом пайплайна best_poly. Для внедрения достаточно одного цельного пайплайна.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b> Сделано. Спасибо за совет, стало яснее. Вывожу отдельно признаки, как комплект артефактов, вдруг с ними что-то сделать надо - а они под рукой.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Изменения:</b> Пункт 8 полностью переделан:
# - вместо использования отложенной выборки X_test - создан тестовый датафрейм
# - Написаны функции формирования таблицы **new_df_ds_s13_visits** и формирования итогового датасета со всеми расчетными показателями
# - проведена проверка модели на "сырых" данных
# </div>

# %% [markdown]
# ## Выводы о результатах работы

# %% [markdown]
# Выведем все результаты

# %%
df_models_results['Prodacshen, метрика>=0.75']=df_models_results['best_score f1_macro'].apply(prod_or_not)    


display('='*115)
display(f'Метрики и параметры полученных моделей:' )
display('='*115)
with pd.option_context('display.max_colwidth', None): 
    display(df_models_results)

display('='*115)


display('='*115)
display("Лучшая модель, train")
display('='*115)

mask = df_models_results['best_score f1_macro'] == df_models_results['best_score f1_macro'].max()

best_model_df = df_models_results[mask]
display(best_model_df)
display('='*115)


print('='*110)
print('Метрики precision, recall, f1 лучшей модели best_lr на test: ')
print('='*110)
display(f'F1 macro: {mean_f1_lr_test:.4f} (+/- {std_f1_test:.4f})') 
display(f'Precision macro: {mean_precision_test:.4f}') 
display(f'Recall macro: {mean_recall_test:.4f}')
print('='*110)


print(f'\nЗначимые признаки')
display('='*110)
display(feature_importance_df_lr.head())
display('='*110)

print('\nClassification report best_lr,  test:\n', classification_report(y_new_test, y_test_pred))
display('='*110)
# Out:
# '==================================================================================================================='
# 'Метрики и параметры полученных моделей:'
# '==================================================================================================================='
#               model_name  best_score f1_macro  \
# 0            Linear_basa             0.968564
# 1        SVC_Linear_basa             0.978171
# 2      Linear_GridSearch             0.983700
# 3  SVC_Linear_GridSearch             0.978200
# 4               SVC_Poly             0.980600
# 5                SVC_RBF             0.976700
#
#                                                               best_params  \
# 0                                                                       -
# 1                                                                       -
# 2                              C=100, class_weight=balanced, solver=lbfgs
# ...

# %% [markdown]
# Построена модель машинного обучения, которая по данным о поведении анонимного пользователя в цифровой среде определет его примерный возраст
#
# В ходе исследования были построены 4 модели:
# - множественной линейной регрессии
# - опорных векторв (svc)
# - полиномиальная модель (poly)
# - радиальная модель (rbf)
#
# Поиск гиперпараметров не значительно улучшил модели lr и svc. Применение нелинейного ядра позволило повысить качество модели до приемлемых значений.
#
# Больше всего на качество модели оказало создание разнообразных числовых признаков.
#
# Наилучшие метрики у нелинейных моделей rbf и poly на уровне 0.97. Для продакшена отобрана с наилучшими - модель логистической регрессии (best_lr).
# Основная её метрика F1-weighted и вспомогательные precision и recall на уровне 0,98. Модель точно определяет возраст пользователя.
#
# Модель рекомендуется для продакшена.
#
# Наиболее влиятельных признаков - три: **character_age** (обобщающие показатели, характеризующие деятельность пользователя (основные характеристики и использование облаков) в зависимости от возраста), **character_ctr** (обобщающие показатели, характеризующие деятельность пользователя (основные характеристики и использование облаков) в зависимости от CTR), **users_activity** (обобщенный показатель активности пользователя: перемножим `'age_category'` (возрастная категория), `'share_of_user_clicks'` (доля интенсивности кликов пользователя в зависимости от категории ads_activity), `'share_of_user_devices'` , `'share_of_visited_websites'`).

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ошибка:</b> Выводы констатируют высокое качество модели (F1-weighted ≈ 0.98), но не проверяют основной критерий задания — F1-macro ≥ 0.75 на CV и на test. С учётом дублирования строк на одного пользователя и использования weighted-метрики вместо macro, заявленное качество модели, вероятно, не отражает её реальную обобщающую способность на новых пользователях. Перед выводом о готовности к внедрению нужно: 1) агрегировать признаки к одной строке на пользователя, 2) пересчитать метрики через f1_macro, 3) явно сверить итоговое значение с порогом 0.75 и на train (CV), и на test.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b> Сделано.
#
# Люман, большое СПАСИБО за твои правки и комментарии!
#
# Не легко мне далась работа. Вроде не сложно, но начинаешь копать и... как бы  выбраться)
#
# Правильно ли было создавать датафрейм для теста? Как можно было лучше? Идея выбирать по 20% записей из каждой таблицы и их объединять мне показалась ещё хуже того, что я наворотила
#
# С нетерпением жду твоей оценки!
#
# Хорошего настроения и позитива )
# </div>
